# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-4.0.1-py3-none-any.whl.metadata (13 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-4.50.1-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.66.4)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Downloading torch-2.6.0-cp312-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.4.2)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (0.28.1)
# Requirement already satisfied: Pillow in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (10.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.11.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.2)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (69.5.1)
# Collecting sympy==1.13.1 (from torch>=1.11.0->sentence-transformers)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2023.10.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.6.2)
# Downloading sentence_transformers-4.0.1-py3-none-any.whl (340 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.6/340.6 kB 3.6 MB/s eta 0:00:0000:0100:01
# Downloading torch-2.6.0-cp312-none-macosx_11_0_arm64.whl (66.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 MB 6.7 MB/s eta 0:00:0000:0100:01
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 6.6 MB/s eta 0:00:0000:0100:01
# Downloading transformers-4.50.1-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 4.5 MB/s eta 0:00:0000:010:01
# Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.4/418.4 kB 4.0 MB/s eta 0:00:00a 0:00:01
# Downloading tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 4.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: sympy, safetensors, torch, tokenizers, transformers, sentence-transformers
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
# Successfully installed safetensors-0.5.3 sentence-transformers-4.0.1 sympy-1.13.1 tokenizers-0.21.1 torch-2.6.0 transformers-4.50.1

# %%
import os
import json
from sentence_transformers import SentenceTransformer, util

# Load pre-trained model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Define the 5 spending categories
categories = [
    "Food & Dining",
    "Housing & Utilities",
    "Transportation",
    "Leisure",
    "Personal Care & Education"
]

# Pre-encode the categories for efficient similarity comparison
category_embeddings = model.encode(categories, convert_to_tensor=True)

# Function to determine the best matching category for a merchant name
def get_closest_category(merchant_name):
    if not merchant_name:
        return "Uncategorized"
    merchant_embedding = model.encode(merchant_name, convert_to_tensor=True)
    similarities = util.cos_sim(merchant_embedding, category_embeddings)
    best_match_index = similarities.argmax().item()
    return categories[best_match_index]

# Get path to users folder (relative to where script is running)
base_dir = os.getcwd()
users_dir = os.path.abspath(os.path.join(base_dir, "..", "users"))

# Process each user folder and update receipt_type
for folder in os.listdir(users_dir):
    folder_path = os.path.join(users_dir, folder)
    if os.path.isdir(folder_path) and folder.startswith("user_"):
        for filename in os.listdir(folder_path):
            file_path = os.path.join(folder_path, filename)
            if os.path.isfile(file_path) and filename.endswith(".json") and filename != "user_total.json":
                try:
                    with open(file_path, "r") as f:
                        receipts = json.load(f)

                    for receipt in receipts:
                        merchant = receipt.get("merchant_name", "")
                        new_category = get_closest_category(merchant)
                        receipt["receipt_type"] = new_category
                        print(f"Updated: '{merchant}' → '{new_category}'")

                    with open(file_path, "w") as f:
                        json.dump(receipts, f, indent=4)
                except Exception as e:
                    print(f"Error updating {file_path}: {e}")
# Out:
# Updated: 'นายการศาล สะภาพร์จะ' → 'Leisure'
# Updated: 'MEAT MARKET' → 'Food & Dining'
# Updated: 'Primo
# Family Restaurant' → 'Food & Dining'
# Updated: 'Thompson-Smith' → 'Transportation'
# Updated: 'Fritz,
# and' → 'Transportation'
# Updated: 'HOME MASTER HARDWARE &
# ELECTRICAL' → 'Housing & Utilities'
# Updated: 'None' → 'Uncategorized'
# Updated: '7-ELEVEN' → 'Food & Dining'
# Updated: 'Peterson LLC' → 'Housing & Utilities'
# Updated: 'OLD TOWN WHITE COFFE' → 'Leisure'
# Updated: 'Subway#44969-0' → 'Transportation'
# Updated: 'BEST BUY' → 'Transportation'
# Updated: 'CAFE S' → 'Food & Dining'
# Updated: 'Jacobs-Curtis' → 'Housing & Utilities'
# Updated: 'Stevens and Sons' → 'Personal Care & Education'
# Updated: 'QuikTrip' → 'Transportation'
# Updated: 'Pasta Divina' → 'Food & Dining'
# Updated: 'food
# Basic$' → 'Food & Dining'
# Updated: 'PINNACLES
# RESTAURANT' → 'Food & Dining'
# Updated: 'PERMAS JAYA JUSCO' → 'Personal Care & Education'
# Updated: 'Fernandez Ltd' → 'Leisure'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'Maxincome Resources Sdin Bhd' → 'Housing & Utilities'
# Updated: 'BEYOND BROTHERS HARDWARE' → 'Transportation'
# Updated: 'Port Charlotte Hotel' → 'Food & Dining'
# Updated: 'Aurora Village' → 'Housing & Utilities'
# Updated: 'RAJAJI INC' → 'Food & Dining'
# Updated: 'Nando's IOI Mall,' → 'Food & Dining'
# Updated: 'Gerbang Alaf Restaurants Sdn Bhd' → 'Food & Dining'
# Updated: 'TARGET' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Walmart' → 'Food & Dining'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'TSH POWER HARDWARE
# TRADING' → 'Transportation'
# Updated: 'RISTORANTE "ALLA BUONA"' → 'Leisure'
# Updated: 'Harvey-Bell' → 'Housing & Utilities'
# Updated: 'Vargas-Hughes' → 'Leisure'
# Updated: 'HMS' → 'Leisure'
# Updated: 'Bella Pasta' → 'Food & Dining'
# Updated: 'Peter Chang' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'BRAVO GELATO' → 'Food & Dining'
# Updated: 'Kenny Rogers Roasters' → 'Food & Dining'
# Updated: 'KOHL'S' → 'Food & Dining'
# Updated: 'PappaRich BMC' → 'Leisure'
# Updated: 'RESTORAN SIAM VILLAGE' → 'Leisure'
# Updated: 'Dunn PLC' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Mission Beach Cafe' → 'Food & Dining'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'COFFE' → 'Transportation'
# Updated: 'HARVEST STATION' → 'Housing & Utilities'
# Updated: 'El Meson Mexican Restaurant' → 'Food & Dining'
# Updated: 'Boyer, Trevino and Hines' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Guardian Health And Beauty Sdn Bhd' → 'Personal Care & Education'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: '99 SPEED MART S/B (519537-X)' → 'Transportation'
# Updated: 'Roy and Sons' → 'Leisure'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'SALVATION
# ARMY' → 'Housing & Utilities'
# Updated: 'BJ'S SAN RAFAEL' → 'Leisure'
# Updated: 'Gerbang Alaf Restaurants Sdn Bhd' → 'Food & Dining'
# Updated: 'Pumpkin Shop' → 'Food & Dining'
# Updated: 'POPULAR BOOK' → 'Leisure'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'Nando's' → 'Food & Dining'
# Updated: 'Walmart' → 'Food & Dining'
# Updated: 'RESTAURANT JIAWEI
# JIAWEI HOUSE' → 'Food & Dining'
# Updated: 'Wilson-Hanson' → 'Transportation'
# Updated: 'BALENCIAGA' → 'Leisure'
# Updated: 'Krueger LLC' → 'Housing & Utilities'
# Updated: '99 SPEED MART S/B (519537-X)' → 'Transportation'
# Updated: 'GOLDILOCKS BAKESHOP, INC.' → 'Food & Dining'
# Updated: 'HENG KEE DELIGHTS BAK KUT TEH.' → 'Food & Dining'
# Updated: 'Shell ISNI PETRO TRADING' → 'Transportation'
# Updated: 'Whitaker-Galloway' → 'Transportation'
# Updated: 'ANY RESTAURANT
# ANYWHERE' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'VERONA ITALICA' → 'Leisure'
# Updated: 'KING'S CONFECTIONERY S/B 273500-U' → 'Food & Dining'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'HOME MASTER HARDWARE &
# ELECTRICAL' → 'Housing & Utilities'
# Updated: 'BHPetromart' → 'Leisure'
# Updated: 'RESTORAN HASSANBISTRO' → 'Leisure'
# Updated: 'Berghotel
# Grosse Scheidegg' → 'Leisure'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'MOONLIGHT CAKE HOUSE SDN BHD' → 'Food & Dining'
# Updated: 'tan woon yann' → 'Leisure'
# Updated: 'Wagner-Weaver' → 'Transportation'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'BLEND CAFE' → 'Food & Dining'
# Updated: 'Davis PLC' → 'Housing & Utilities'
# Updated: 'GLENDALE CAR WASH/DETAIL CENTER' → 'Housing & Utilities'
# Updated: 'AEON CO. (M) BHD' → 'Leisure'
# Updated: 'SELASIH EKSLUSIF SDN BHD' → 'Transportation'
# Updated: 'MR D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'Smith LLC' → 'Housing & Utilities'
# Updated: 'Harrison-Harris' → 'Transportation'
# Updated: 'MIGROS' → 'Leisure'
# Updated: 'ONE ONE THREE SEAFOOD RESTAURANT SDN BHD' → 'Food & Dining'
# Updated: 'ONE ONE THREE SEAFOOD RESTAURANT SDN BHD' → 'Food & Dining'
# Updated: 'Taco Time - Kenmore' → 'Food & Dining'
# Updated: 'MR. D.I.Y. SDN BHD' → 'Transportation'
# Updated: 'Truluck's of Miami' → 'Food & Dining'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Roberts Group' → 'Leisure'
# Updated: 'La Isla' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'MENCHIE'S RANCHO CUCAMONGA' → 'Housing & Utilities'
# Updated: 'Restaurant KEUNG KEE' → 'Food & Dining'
# Updated: 'Harris and Sons' → 'Transportation'
# Updated: 'HOME MASTER HARDWARE &
# ELECTRICAL' → 'Housing & Utilities'
# Updated: 'PORTUGAL WINE BAR & GRILL' → 'Food & Dining'
# Updated: 'Barton-Higgins' → 'Food & Dining'
# Updated: 'YONG CEN ENTERPRISE' → 'Transportation'
# Updated: 'TARGET' → 'Transportation'
# Updated: 'Smith, Anderson and Johnson' → 'Transportation'
# Updated: 'ALBETOS' → 'Leisure'
# Updated: 'Stam Secret Sdn Bhd' → 'Transportation'
# Updated: 'Wise and Sons' → 'Leisure'
# Updated: 'LIVE9 PHARMACY SDN BHD' → 'Transportation'
# Updated: 'Roti
# man
# bakery' → 'Food & Dining'
# Updated: 'PYT' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'KTCHN Restaurant' → 'Food & Dining'
# Updated: 'GIANT' → 'Transportation'
# Updated: 'Marche Moevenpick' → 'Transportation'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'Shields, Copeland and Gallegos' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Berghotel
# Grosse Scheidegg' → 'Leisure'
# Updated: 'WESTERN EASTERN
# - STATIONERY SDN. BHD' → 'Transportation'
# Updated: 'Panda Express' → 'Transportation'
# Updated: 'LIVE9 PHARMACY SDN BHD' → 'Transportation'
# Updated: 'TIRE' → 'Transportation'
# Updated: 'Hanson PLC' → 'Food & Dining'
# Updated: 'KAMRAN SIDDIQUI PHARMACY LIMITED' → 'Personal Care & Education'
# Updated: 'FOOD OPERA
# PADANG PADANG' → 'Food & Dining'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: '(EDAI BUKU NEW ACHEIVERS' → 'Leisure'
# Updated: '"The Restaurant"' → 'Food & Dining'
# Updated: 'Henson, Mccarthy and Hart
# Garcia Group' → 'Food & Dining'
# Updated: 'F W WOOLWORTH' → 'Housing & Utilities'
# Updated: 'AIK HUAT HARDWARE
# ENTERPRISE (SETIA
# ALAM) SDN BHD' → 'Food & Dining'
# Updated: 'Tay Ho Oakland' → 'Food & Dining'
# Updated: 'BERRY'S CAKE HOUSE' → 'Food & Dining'
# Updated: 'Le Wazawan Medieval Restaurant' → 'Food & Dining'
# Updated: 'McDonald's Shell Mahkota Cheras DT' → 'Food & Dining'
# Updated: 'STANLEY'S FRUIT MARKE' → 'Food & Dining'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'Smoke City Market' → 'Housing & Utilities'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'Triple Six Point Enterprise 666' → 'Food & Dining'
# Updated: 'PASAR MINI JIN SENG' → 'Food & Dining'
# Updated: 'ONE ONE THREE SEAFOOD RESTAURANT SDN BHD' → 'Food & Dining'
# Updated: 'Reynolds, Gonzales and Meyer' → 'Housing & Utilities'
# Updated: 'The Saxon Hotel' → 'Leisure'
# Updated: 'SOON HUAT MACHINERY ENTERPRISE' → 'Transportation'
# Updated: 'SHIZEN' → 'Food & Dining'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'Lalo's Mexican at Navy Pier' → 'Food & Dining'
# Updated: 'HERO DISTRIBUTION SDN BHD' → 'Housing & Utilities'
# Updated: 'DIGI TELECOMMUNICATIONS SDN BHD' → 'Transportation'
# Updated: 'Zuniga and Sons' → 'Leisure'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'ANANDHA BHAVAN A/C' → 'Personal Care & Education'
# Updated: 'Bistecca
# Restaurant Pte Ltd' → 'Food & Dining'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'Kiwiana Restaurant' → 'Food & Dining'
# Updated: 'HIRO JAPANESE RESTAURANT' → 'Food & Dining'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'Segi Cash & Carry Sdn.Bhd' → 'Transportation'
# Updated: 'PASARAYA
# BORONG PINTAR SDN BHD' → 'Transportation'
# Updated: 'Khansama Tandoori
# Restaurant' → 'Food & Dining'
# Updated: 'TED HENG STATIONERY & BOOKS' → 'Leisure'
# Updated: 'WALMART' → 'Food & Dining'
# Updated: 'SHELL OIL PRODUCTS US' → 'Housing & Utilities'
# Updated: 'TARGET' → 'Transportation'
# Updated: 'Brazilian Steak House' → 'Food & Dining'
# Updated: 'S&Y STATIONERY' → 'Transportation'
# Updated: 'L' OUSTAGOU
# RESTAURANT AUVERGNAT' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'TIP TOP MEATS' → 'Food & Dining'
# Updated: 'LA CAMERA' → 'Transportation'
# Updated: 'Vic & Anthony's Steakhouse' → 'Food & Dining'
# Updated: 'Panda Express' → 'Transportation'
# Updated: 'MODERN DEPOT SDN BHD' → 'Transportation'
# Updated: 'Drips
# Bakery Cafe' → 'Food & Dining'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'Bloody Mary 's' → 'Food & Dining'
# Updated: 'Espinoza Group' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'LOTUS OF SIAM' → 'Leisure'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'The Fifty Six Bar & Lounge' → 'Food & Dining'
# Updated: 'Royaltea' → 'Leisure'
# Updated: 'LIGHTROOM GALLERY SDN BHD' → 'Transportation'
# Updated: 'MRP TRAVEL PLAZA' → 'Transportation'
# Updated: 'Williams-Odom' → 'Leisure'
# Updated: 'RSH NU SENTRAL' → 'Transportation'
# Updated: 'CVS/pharmacy' → 'Personal Care & Education'
# Updated: 'LIM SENG THO HARDWARE TRADING' → 'Transportation'
# Updated: 'PETRODELI ENTERPRISE' → 'Leisure'
# Updated: 'rue 21' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Jones PLC' → 'Housing & Utilities'
# Updated: 'TARGET' → 'Transportation'
# Updated: 'MR. D.I.Y. (KUCHAI) SDN BHD' → 'Transportation'
# Updated: 'Denny's Restaurant' → 'Food & Dining'
# Updated: 'HMSHost' → 'Leisure'
# Updated: 'Taj Mahal' → 'Transportation'
# Updated: 'Nicholson and Sons' → 'Personal Care & Education'
# Updated: 'None' → 'Uncategorized'
# Updated: 'NUDORU Ramen Bar' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'VERC MOBIL' → 'Transportation'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'Baker-Jackson' → 'Food & Dining'
# Updated: 'MR D.I.Y. (JOHOR) SDN BHD' → 'Transportation'
# Updated: 'DAVID YURMAN' → 'Food & Dining'
# Updated: 'Morrisons' → 'Transportation'
# Updated: 'Golden Arches Restaurants Sdn Bhd' → 'Food & Dining'
# Updated: 'Sushi Garden Restaurant' → 'Food & Dining'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'CHATPATA RESTAURANT INC' → 'Food & Dining'
# Updated: 'Carolina Ale House' → 'Food & Dining'
# Updated: 'EIGHT OUNCE
# COFFEE' → 'Transportation'
# Updated: 'Smart Paak
# AIRPORT PARKINGN' → 'Transportation'
# Updated: 'Hood Ranch' → 'Food & Dining'
# Updated: 'SAFEWAY' → 'Transportation'
# Updated: 'AIK HUAT HARDWARE
# ENTERPRISE (SETIA
# ALAM) SDN BHD' → 'Food & Dining'
# Updated: 'Collins, Barrett and Schroeder' → 'Food & Dining'
# Updated: 'Mendoza Group' → 'Leisure'
# Updated: 'Wright-Lucas' → 'Transportation'
# Updated: 'Gordon Ramsay Steak' → 'Food & Dining'
# Updated: 'meijer' → 'Food & Dining'
# Updated: 'DIONYSUS MANSION' → 'Leisure'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'MOOYAH Burgers Fries
# & Shakes' → 'Food & Dining'
# Updated: 'MAGASIN CHIN LEE' → 'Food & Dining'
# Updated: 'H-4
# R-1-2' → 'Transportation'
# Updated: 'Cracker Barrel' → 'Food & Dining'
# Updated: 'PLATINUM RACKING SDN BHD' → 'Transportation'
# Updated: 'BEMED (SP) SDN. BHD.' → 'Transportation'
# Updated: 'The Victoria Falls Hotel' → 'Leisure'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'Macy's' → 'Food & Dining'
# Updated: 'Cartwheel!' → 'Transportation'
# Updated: 'ATLANTIS
# NOBU' → 'Leisure'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'ITSILRESTAURANT' → 'Leisure'
# Updated: 'TEMPLE BAR
# THE' → 'Food & Dining'
# Updated: 'Squeaky Clean Car Wash' → 'Personal Care & Education'
# Updated: 'CTC/Fuelco' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'GameStop' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Barnes Ltd' → 'Leisure'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: '85 C BAKERY' → 'Food & Dining'
# Updated: 'Nobu Malibu' → 'Transportation'
# Updated: 'RED COW' → 'Food & Dining'
# Updated: 'Spiral Diner & Bakery' → 'Food & Dining'
# Updated: 'BREAD OF LIFE' → 'Food & Dining'
# Updated: 'T.G.I. FRIDAY 'S' → 'Leisure'
# Updated: 'BALENCIAGA' → 'Leisure'
# Updated: 'Dall' → 'Leisure'
# Updated: 'BEMED (SP) SDN. BHD.' → 'Transportation'
# Updated: 'LIGHTROOM GALLERY SDN BHD' → 'Transportation'
# Updated: 'VINELAND SHELL' → 'Food & Dining'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: '7-ELEVEN' → 'Food & Dining'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'Gourdough's Public House' → 'Housing & Utilities'
# Updated: 'PINGHWAI TRADING SDN BHD' → 'Transportation'
# Updated: 'Jones Ltd' → 'Housing & Utilities'
# Updated: 'TASTE S.R.L.' → 'Food & Dining'
# Updated: 'TAQUERIA
# PICO DE GALLO' → 'Leisure'
# Updated: 'MIGALatsar' → 'Food & Dining'
# Updated: 'Subway#4415-0' → 'Transportation'
# Updated: 'RESTAURANT
# PICCADILLY
# MASALA' → 'Food & Dining'
# Updated: 'YONG CEN ENTERPRISE' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'รี่อูภาณุใด การยู ริน สํ' → 'Transportation'
# Updated: 'Queensboro Car Wash' → 'Transportation'
# Updated: 'CPI ROCKU SDN. BHD.' → 'Transportation'
# Updated: 'Argonaut Diner 2000' → 'Food & Dining'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'McDonald's Shell Mahkota Cheras DT' → 'Food & Dining'
# Updated: '99 SPEED MART S/B (519537-X)' → 'Transportation'
# Updated: 'TARGET' → 'Transportation'
# Updated: 'OCEANA BEACH INN' → 'Food & Dining'
# Updated: 'KOH SENG HARDWARE' → 'Food & Dining'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'EDGEMEAD SUPERSPAR' → 'Leisure'
# Updated: 'Movenpick JLT' → 'Transportation'
# Updated: 'Grand Nok' → 'Leisure'
# Updated: 'Philipp Plein Paris' → 'Leisure'
# Updated: 'KEDAI PAPAN YEW CHUAN' → 'Food & Dining'
# Updated: 'Source' → 'Transportation'
# Updated: 'SUPREME' → 'Leisure'
# Updated: 'CAFE PARISIEN LARCHMONT LLC' → 'Food & Dining'
# Updated: 'PINGHWAI TRADING SDN BHD' → 'Transportation'
# Updated: 'La Parrilla' → 'Food & Dining'
# Updated: 'Stop&Shop' → 'Transportation'
# Updated: 'Miller-Williams' → 'Transportation'
# Updated: 'ELKEN SERVICE SDN BHD' → 'Transportation'
# Updated: 'TARGET' → 'Transportation'
# Updated: 'POP TATES KORUM HALL' → 'Food & Dining'
# Updated: 'Rustom's' → 'Leisure'
# Updated: 'HOME MASTER HARDWARE &
# ELECTRICAL' → 'Housing & Utilities'
# Updated: 'Ferrara' → 'Leisure'
# Updated: 'PIUS
# PREISE' → 'Personal Care & Education'
# Updated: 'Restaurant Aposto' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Koh Grill&Sushi Bar' → 'Food & Dining'
# Updated: 'West-Anderson
# Wilson and' → 'Transportation'
# Updated: 'pizza
# Hust' → 'Food & Dining'
# Updated: 'SHELL' → 'Transportation'
# Updated: 'Dona Mercedes Restaurant' → 'Food & Dining'
# Updated: 'Barnes & Noble Booksellers' → 'Personal Care & Education'
# Updated: 'LA BAGUETTE' → 'Food & Dining'
# Updated: 'ALDI' → 'Housing & Utilities'
# Updated: 'PORCH DOGS' → 'Food & Dining'
# Updated: 'MIZU MENTAI SDN. BHD.' → 'Leisure'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'TOKYO KITCHEN (CITTA MALL)' → 'Food & Dining'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'WESTMINSTER CO-OP' → 'Housing & Utilities'
# Updated: 'Sage General Store' → 'Leisure'
# Updated: 'Gavin DeGraw' → 'Housing & Utilities'
# Updated: 'Houston Group
# Harding Inc' → 'Housing & Utilities'
# Updated: 'MEI LET RESTAURANT' → 'Food & Dining'
# Updated: 'Banco de Bogotá' → 'Housing & Utilities'
# Updated: 'Publix' → 'Food & Dining'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'BEMED (SP) SDN. BHD.' → 'Transportation'
# Updated: 'Mitcheldean Garage' → 'Housing & Utilities'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'Panda Express' → 'Transportation'
# Updated: 'GAYLORD LONDON' → 'Leisure'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'ARTRANGE STATIONERS & PRINT SDN BHD' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Becon Enterprise Sdn Bhd' → 'Food & Dining'
# Updated: 'AEON CO. (M) BHD' → 'Leisure'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'Walmart' → 'Food & Dining'
# Updated: 'WAL-MART' → 'Food & Dining'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'Hardee's' → 'Transportation'
# Updated: 'Harvey Norman M'sia Paradigm Mall' → 'Housing & Utilities'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Gibson PLC' → 'Housing & Utilities'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'Lewis and Sons' → 'Transportation'
# Updated: 'Kellner und Hühnlein
# Gastronomie GmbH' → 'Food & Dining'
# Updated: 'FIVE GUYS' → 'Transportation'
# Updated: 'LA STATIONERY SDN BHD (640899-P)' → 'Transportation'
# Updated: 'Old Town White Coffe' → 'Leisure'
# Updated: 'Jollibee®' → 'Food & Dining'
# Updated: 'Moore Ltd' → 'Leisure'
# Updated: 'Kalamazoo Beer Exchange' → 'Transportation'
# Updated: 'MR. D.1.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'York-Crawford' → 'Transportation'
# Updated: 'WINGS & THINGS' → 'Food & Dining'
# Updated: 'DOLLAR TREE STORES, INC.' → 'Housing & Utilities'
# Updated: 'CHRISTOPHER'S
# CAKE SHOP' → 'Food & Dining'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Golden Arches Restaurants Sdn Bhd' → 'Food & Dining'
# Updated: 'STARBUCKS COFFEE ESPAÑA,SL' → 'Transportation'
# Updated: 'AEON CO. (M) BHD.' → 'Leisure'
# Updated: 'PRINT EXPERT SDN BHD' → 'Food & Dining'
# Updated: 'DAGHIN Enterprises Ltd.' → 'Transportation'
# Updated: 'MEAT
# & POTATOES' → 'Food & Dining'
# Updated: 'Kitsch at Embassy' → 'Personal Care & Education'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Mason-Cross' → 'Leisure'
# Updated: 'Cumberland Farms' → 'Food & Dining'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'The Press Room' → 'Food & Dining'
# Updated: 'Farmasi Maluri S/B(587969-U)' → 'Housing & Utilities'
# Updated: 'Cruz LLC' → 'Transportation'
# Updated: 'Strickland, Ferguson and Ellis' → 'Housing & Utilities'
# Updated: 'YAUATCHA' → 'Leisure'
# Updated: 'Clay PLC' → 'Transportation'
# Updated: 'Lady M West Third' → 'Food & Dining'
# Updated: 'Cane's
# CHICKEN FINGERS' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'GIOVANNI'S
# WINE BAR & RISTORANTE' → 'Food & Dining'
# Updated: 'Arizona Five Palms' → 'Food & Dining'
# Updated: 'Trinity Restaurant' → 'Food & Dining'
# Updated: 'Loulay
# Kitchen' → 'Food & Dining'
# Updated: 'HYOTAN JAPANESE
# RESTAURANT' → 'Food & Dining'
# Updated: 'Harrell LLC' → 'Transportation'
# Updated: 'Rihanna's Caribbean Restaurant' → 'Food & Dining'
# Updated: 'COMPTOIR DU LOUVRE' → 'Leisure'
# Updated: 'VOLUME ONE BOOKS INC' → 'Personal Care & Education'
# Updated: 'TED HENG STATIONERY & BOOKS' → 'Leisure'
# Updated: 'Dreamland Aqua Park' → 'Leisure'
# Updated: 'POPULAR BOOK' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'RESTAURANT CROSTO' → 'Food & Dining'
# Updated: 'BORDERS' → 'Transportation'
# Updated: 'Boston Pizza' → 'Food & Dining'
# Updated: 'Bates LLC' → 'Leisure'
# Updated: 'HON HWA HARDWARE TRADING' → 'Transportation'
# Updated: 'FISH' → 'Food & Dining'
# Updated: 'Amici Conyers' → 'Leisure'
# Updated: 'ASTONS
# SPECIALITIES-CT1' → 'Transportation'
# Updated: 'MR. D.I.Y. (KUCHAI) SDN BHD' → 'Transportation'
# Updated: 'BIZ LINK' → 'Transportation'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'PEGASUS ON THE FLY' → 'Leisure'
# Updated: 'COSITAS RICAS' → 'Leisure'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'SHELL OIL PRODUCTS US' → 'Housing & Utilities'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'CHRIS 'S
# HAMBURGERS' → 'Food & Dining'
# Updated: 'Nando's 101 City Mall' → 'Housing & Utilities'
# Updated: 'De Maximum Thai Express Sdn Bhd' → 'Transportation'
# Updated: 'VIA EMILIA 9' → 'Transportation'
# Updated: 'MARGARITA GRILL
# PINO' → 'Food & Dining'
# Updated: '99 SPEED WART S/B' → 'Transportation'
# Updated: 'Blue Bear Tavern' → 'Food & Dining'
# Updated: 'Greene Ltd' → 'Leisure'
# Updated: 'Taken Pier 195' → 'Transportation'
# Updated: 'Vapiano Disney' → 'Leisure'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'BHPetrol Subang Airport' → 'Transportation'
# Updated: 'FANZZ - WESTMINSTER,CA' → 'Housing & Utilities'
# Updated: 'THE LICHENS AKTIE' → 'Food & Dining'
# Updated: 'C W KHOO HARDWARE SDN BHD' → 'Transportation'
# Updated: 'oasiria' → 'Leisure'
# Updated: 'Salon Du Chocolat' → 'Food & Dining'
# Updated: 'LE SWANN' → 'Leisure'
# Updated: 'Jackson-Martinez' → 'Transportation'
# Updated: 'GUDANG HASIL RESTAURANT SDN BHD' → 'Food & Dining'
# Updated: 'BOA' → 'Transportation'
# Updated: 'Walton PLC' → 'Housing & Utilities'
# Updated: 'Gardner, Tucker and' → 'Food & Dining'
# Updated: 'INDUSTRIAL HOTELERA BEDFORD, 5 L' → 'Housing & Utilities'
# Updated: 'Opium Mar SL' → 'Leisure'
# Updated: 'DARTMOUTH BOOKSTORE, INC.' → 'Food & Dining'
# Updated: 'Walmart' → 'Food & Dining'
# Updated: 'Yates and Sons' → 'Personal Care & Education'
# Updated: 'REGINEI ICECREAM' → 'Leisure'
# Updated: 'WESTMINSTER KITCHEN' → 'Food & Dining'
# Updated: 'RAPID RAIL SDN BHD' → 'Transportation'
# Updated: 'SWETT 'S' → 'Food & Dining'
# Updated: 'Harvey Norman M'sia Paradigm Mall' → 'Housing & Utilities'
# Updated: 'MR. D.I.Y. (KUCHAI) SDN BHD' → 'Transportation'
# Updated: 'Authentio Indonesian Butine' → 'Food & Dining'
# Updated: 'GL HANDICRAFT & TAILORING' → 'Transportation'
# Updated: 'ASIA MART' → 'Food & Dining'
# Updated: 'Golden
# Opear
# Cafe' → 'Food & Dining'
# Updated: 'THE MARCO POLO KITCH
# BUKIT INDAH' → 'Leisure'
# Updated: 'Navarro-Jensen' → 'Transportation'
# Updated: 'Kemp and Sons' → 'Personal Care & Education'
# Updated: 'AIK HUAT HARDWARE
# ENTERPRISE (SETIA
# ALAM) SDN BHD' → 'Food & Dining'
# Updated: 'THE STORE (MALAYSIA) SDN BHD' → 'Transportation'
# Updated: 'Walmart' → 'Food & Dining'
# Updated: 'Butler PLC' → 'Food & Dining'
# Updated: 'AMPHAWA THAI TEA & CO.' → 'Food & Dining'
# Updated: 'Grant Inc' → 'Housing & Utilities'
# Updated: 'West-Hodges' → 'Transportation'
# Updated: 'Oconnor Inc' → 'Leisure'
# Updated: 'Milano
# Restaurant' → 'Food & Dining'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'Applebee's' → 'Food & Dining'
# Updated: 'Publix' → 'Food & Dining'
# Updated: 'PUMP MAINSIDE SRU ST' → 'Housing & Utilities'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Primo
# Family Restaurant' → 'Food & Dining'
# Updated: 'ADVANCO COMPANY' → 'Housing & Utilities'
# Updated: 'RAJ GAYLORD
# INDIAN RESTAURANT.' → 'Food & Dining'
# Updated: 'EL CHICO MEXICAN RESTAURANT' → 'Food & Dining'
# Updated: 'GREAT ZONE HOUSEHOLD CENTRE SDN BHD' → 'Housing & Utilities'
# Updated: 'BARNEY'S BURGERS' → 'Food & Dining'
# Updated: 'BRUGNONI RENZO' → 'Leisure'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'Chick-fil-a' → 'Food & Dining'
# Updated: 'TRANSIT' → 'Transportation'
# Updated: 'BURGER' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Subway#24037-0' → 'Transportation'
# Updated: 'PUSAT DAGANGAN PHILEO DAMANSARA' → 'Personal Care & Education'
# Updated: 'PREMIO STATIONERY SDN BHD' → 'Transportation'
# Updated: 'KFC GOSIER DRIVE' → 'Transportation'
# Updated: 'MOD Pizza' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'DAIRY QUEEN' → 'Food & Dining'
# Updated: 'Shangri-La's' → 'Food & Dining'
# Updated: 'Delmonico's' → 'Food & Dining'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'RESTORAN HOETIM' → 'Leisure'
# Updated: 'Shaw and Sons' → 'Leisure'
# Updated: 'VERBENA CONFECTIONERY SDN BHD' → 'Food & Dining'
# Updated: 'FUEL KING SERVICE CENTER' → 'Transportation'
# Updated: 'SEN LEE HEONG RESTAURANT' → 'Food & Dining'
# Updated: 'Ted's Montana Grill' → 'Food & Dining'
# Updated: 'Taste Of The World Sdn Bhd' → 'Food & Dining'
# Updated: 'MEI LET RESTAURANT' → 'Food & Dining'
# Updated: '*Nando's*' → 'Leisure'
# Updated: 'COSITAS RICAS' → 'Leisure'
# Updated: 'SINNATHAMBY HOLDINGS
# SDN. BHD.' → 'Leisure'
# Updated: 'Carmichael CarWash' → 'Personal Care & Education'
# Updated: 'Jones and' → 'Food & Dining'
# Updated: 'CHIPOTLE' → 'Food & Dining'
# Updated: 'Triple Six Point Enterprise 666' → 'Food & Dining'
# Updated: 'DOMINO'S PIZZA TAMAN UNIVERSITI' → 'Food & Dining'
# Updated: 'Swlas Chalet' → 'Leisure'
# Updated: 'Romano's Macaroni Grill' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'BEMED (SP) SDN. BHD.' → 'Transportation'
# Updated: 'Yam Fresh' → 'Leisure'
# Updated: 'COMMANDER'S PALACE' → 'Leisure'
# Updated: 'ATHENS GENERAL MAIL FACILITY' → 'Transportation'
# Updated: 'Broadview Marketing Sdn Bhd (728364-M)' → 'Transportation'
# Updated: 'IKANO HANDEL SDN BHD' → 'Transportation'
# Updated: 'LOREM SHOP' → 'Food & Dining'
# Updated: 'PRODUITS DU SUD-OUEST' → 'Housing & Utilities'
# Updated: 'CARL'S JR 1100375' → 'Transportation'
# Updated: 'The UPS Store' → 'Transportation'
# Updated: 'LIZZY'S' → 'Housing & Utilities'
# Updated: 'The Tower Bar' → 'Transportation'
# Updated: 'AEON CO. (M) BHD.' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Michaels' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Lin Buffet' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'TRADER JOE'S' → 'Food & Dining'
# Updated: 'ASDA' → 'Personal Care & Education'
# Updated: 'HAI-O RAYA BHD (169199-V)' → 'Leisure'
# Updated: 'Saung Udio Souvenir Shop' → 'Transportation'
# Updated: 'WESTERN EASTERN
# STATIONERY SDN. BHD' → 'Transportation'
# Updated: 'alamy' → 'Housing & Utilities'
# Updated: 'None' → 'Uncategorized'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Segi Cash & Carry Sdn.Bhd' → 'Transportation'
# Updated: 'RESTAURANT JIAWEI' → 'Food & Dining'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'Stanton PLC
# Davis-Jackson' → 'Housing & Utilities'
# Updated: 'Dunkin' Donuts' → 'Food & Dining'
# Updated: 'SALTWATER GRILL' → 'Food & Dining'
# Updated: 'LIAN HING STATIONERY SDN BHD' → 'Transportation'
# Updated: 'MUN HENG ELECTRICAL &
# HARDWARE SUPPLY' → 'Housing & Utilities'
# Updated: 'CIUD' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'LIM SENG THO HARDWARE TRADING' → 'Transportation'
# Updated: 'Pacheco-Booker' → 'Transportation'
# Updated: 'MASALA ZONE
# SOHO
# Indian Food' → 'Food & Dining'
# Updated: 'INN A DAY
# JIN CHIENG SENG' → 'Leisure'
# Updated: 'La Maree' → 'Leisure'
# Updated: 'SNAPPY MOBIL' → 'Transportation'
# Updated: 'ROCK ROAD SEAFOOD RESTAURANT SDN BHD' → 'Food & Dining'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'TESCO
# extra' → 'Food & Dining'
# Updated: 'Panera Bread' → 'Food & Dining'
# Updated: 'Thai Gusto' → 'Food & Dining'
# Updated: 'SOUP & PORRIDGE' → 'Food & Dining'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'Segi Cash & Carry Sdn. Bhd.' → 'Transportation'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'alamy' → 'Housing & Utilities'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'Papa Johns' → 'Food & Dining'
# Updated: 'MR. D.I.Y. (KUCHAI) SDN BHD' → 'Transportation'
# Updated: 'ONE ONE THREE SEAFOOD RESTAURANT SDN BHD' → 'Food & Dining'
# Updated: 'Guacamole' → 'Food & Dining'
# Updated: 'Keith LLC' → 'Transportation'
# Updated: 'Baby Sumo Sushi & Steakhouse' → 'Food & Dining'
# Updated: 'RESTAURANT SALINE' → 'Food & Dining'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'IKEA Cheras' → 'Food & Dining'
# Updated: 'BENS INDEPENDENT GROCER SDN. BHD' → 'Transportation'
# Updated: 'meijer' → 'Food & Dining'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'Harris LLC' → 'Transportation'
# Updated: 'SANG KEE CHERAS RESTAURANT' → 'Food & Dining'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'LEE WAH FLORIST SDN BHD' → 'Food & Dining'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'Five Below - Waldorf' → 'Leisure'
# Updated: 'Wagner PLC' → 'Housing & Utilities'
# Updated: 'PASARAYA CINWA SDN BHD' → 'Transportation'
# Updated: 'Luna Grill Oxnard' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'LA NONNA' → 'Leisure'
# Updated: 'TGI Fridays UK' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Dawson-Strickland' → 'Transportation'
# Updated: 'Mitchells Restaurant' → 'Food & Dining'
# Updated: 'McDonald's Restaurant' → 'Food & Dining'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: '(N)' → 'Transportation'
# Updated: 'WESTERN EASTERN
# STATIONERY SDN. BHD' → 'Transportation'
# Updated: 'The Butcher Shop & Grill' → 'Food & Dining'
# Updated: 'S&Y STATIONERY' → 'Transportation'
# Updated: 'Cohen LLC' → 'Leisure'
# Updated: 'MR. D.I.Y. (KUCHAI) SDN BHD' → 'Transportation'
# Updated: 'banh mi cafe sdn bhd' → 'Food & Dining'
# Updated: 'Bombay Blues Restaurant' → 'Food & Dining'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'Applewoods' → 'Leisure'
# Updated: 'Restaurant at Elderberry Pond' → 'Food & Dining'
# Updated: 'McDonald's Hazeldonk-West' → 'Food & Dining'
# Updated: 'SOBEYS' → 'Transportation'
# Updated: 'The Peanut Shop of Savannah' → 'Food & Dining'
# Updated: 'Shell ISNI PETRO TRADING' → 'Transportation'
# Updated: 'Anzel Advertising (M) Sdn bhd' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Nobu Hotel Ibiza Bay' → 'Leisure'
# Updated: 'CLOCKED!' → 'Leisure'
# Updated: 'Mr. M's Hot Wings & Things Inc' → 'Food & Dining'
# Updated: 'Cracker Barrel' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'H20 HAND CARWASH & DETAIL' → 'Personal Care & Education'
# Updated: 'Eco Wash - Cumming' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Laque Nail Bar &
# Beauty Lounge, Inc.' → 'Food & Dining'
# Updated: 'TONYMOLY VIVA CITY' → 'Leisure'
# Updated: 'YHM Aeon Tebrau City' → 'Leisure'
# Updated: 'Smith-Petersen' → 'Transportation'
# Updated: 'TK DIVISION KITCHEN SDN BHD' → 'Food & Dining'
# Updated: 'Newark Buffet' → 'Food & Dining'
# Updated: 'CARRABBA'S' → 'Food & Dining'
# Updated: 'ANY RESTAURANT
# ANYWHERE' → 'Food & Dining'
# Updated: 'Meatology' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'SHELL' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'KENT KWIK' → 'Transportation'
# Updated: 'AEON CO. (M) BHD' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'KFC KL CENTRAL' → 'Food & Dining'
# Updated: 'GUS & PAUL'S' → 'Housing & Utilities'
# Updated: 'Walmart' → 'Food & Dining'
# Updated: 'POPULAR BOOK
# CO. (M) SDN BHD' → 'Transportation'
# Updated: 'Hoododdy Burger Bar' → 'Food & Dining'
# Updated: 'saras' → 'Transportation'
# Updated: 'Alvarez-Woods' → 'Transportation'
# Updated: 'TS TOOLS HARDWARE & MACHINERY SUR ESHD' → 'Transportation'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'Build-A-Bear Workshop' → 'Housing & Utilities'
# Updated: 'Taylor and Sons' → 'Housing & Utilities'
# Updated: 'Pita Pita - Lombard' → 'Leisure'
# Updated: 'New Asia Buffet' → 'Food & Dining'
# Updated: 'Albertsons®' → 'Food & Dining'
# Updated: 'Loaded Cafe' → 'Food & Dining'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'Goodwill Outlet' → 'Housing & Utilities'
# Updated: 'HAWWI ETHIOPIAN RESTAU' → 'Food & Dining'
# Updated: 'MIGUELS MEXICAN' → 'Transportation'
# Updated: 'The Real Greek Hoxton' → 'Transportation'
# Updated: 'LIGHTROOM GALLERY SDN BHD' → 'Transportation'
# Updated: 'Campbell PLC' → 'Housing & Utilities'
# Updated: 'CANVAS cafe & bakery' → 'Food & Dining'
# Updated: 'SATU KAMPUNG ENTERPRISE SDN BHD' → 'Transportation'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'NIKE' → 'Leisure'
# Updated: 'FARMACIA' → 'Food & Dining'
# Updated: 'Walmart' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Conservatory Restaurant' → 'Food & Dining'
# Updated: 'THE PASTA BOWL COMPANY' → 'Food & Dining'
# Updated: 'Q Ganha Pão Activ. Hot., Lda' → 'Leisure'
# Updated: 'C W KHOO HARDWARE SDN BHD' → 'Transportation'
# Updated: 'Boston Tea Party' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'CHECKERS HYPERMARKET SDN BHD' → 'Transportation'
# Updated: 'Aloha Pali' → 'Personal Care & Education'
# Updated: 'MY MYDIN SDN BHD' → 'Transportation'
# Updated: 'Becon Enterprise Sdn Bhd' → 'Food & Dining'
# Updated: 'PIONNER' → 'Leisure'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'Trendz Restaurant and Wine Bar' → 'Food & Dining'
# Updated: 'Robinson, Cannon and Ray' → 'Housing & Utilities'
# Updated: 'ShopRite' → 'Food & Dining'
# Updated: 'California Pizza Kitchen(TKO)' → 'Food & Dining'
# Updated: 'KOH SENG HARDWARE' → 'Food & Dining'
# Updated: 'Walgreens' → 'Personal Care & Education'
# Updated: 'BAR LOUIE' → 'Food & Dining'
# Updated: 'IKANO HANDEL SDN BHD' → 'Transportation'
# Updated: 'TOMS Mall of America' → 'Food & Dining'
# Updated: 'Bollywood
# Indian Restaurant' → 'Food & Dining'
# Updated: 'JW MARRIOTT HOTEL BANGKOK' → 'Food & Dining'
# Updated: 'POPULAR BOOK
# CO. (M) SDN BHD' → 'Transportation'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'PANA JAYA ENTERPRISE' → 'Leisure'
# Updated: 'Barton, Garcia and Richards' → 'Food & Dining'
# Updated: 'PappaRich BMC' → 'Leisure'
# Updated: 'Kongress Hotel' → 'Leisure'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'Vasanta Bhavan' → 'Food & Dining'
# Updated: 'ZEITOUN CAFÉ' → 'Food & Dining'
# Updated: 'McDonald's Restaurants Limited' → 'Food & Dining'
# Updated: 'RESTORAN IBRAHIM MAJU SB' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Mc Donald's' → 'Housing & Utilities'
# Updated: 'FRANK'S ITALIAN RESTAURAN' → 'Food & Dining'
# Updated: 'IKANO HANDEL SDN BHD' → 'Transportation'
# Updated: 'Kildare Village Outlet Shopping' → 'Food & Dining'
# Updated: 'BURGER CRAFT' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Car Spa' → 'Transportation'
# Updated: 'Henderson-Diaz
# Arroyo-Fletcher' → 'Personal Care & Education'
# Updated: 'Jeni's Splendid Ice Creams, LLC' → 'Food & Dining'
# Updated: 'Hess and Sons' → 'Transportation'
# Updated: 'Marina Bar and Grill' → 'Food & Dining'
# Updated: 'WHOLE
# FOODS®' → 'Food & Dining'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'KEDAI BUKU NEW ACHEIVERS' → 'Food & Dining'
# Updated: 'Super Ninety Nine Sdn.Bhd.' → 'Transportation'
# Updated: 'Freeman-Taylor' → 'Housing & Utilities'
# Updated: 'THE BUFFALO' → 'Leisure'
# Updated: 'Duncan, Montes and Cooper' → 'Housing & Utilities'
# Updated: 'Harrison-Pierce' → 'Food & Dining'
# Updated: 'YIN MA (M) SDN.BHD.' → 'Personal Care & Education'
# Updated: 'Davis and Sons' → 'Transportation'
# Updated: 'SS PARADISE' → 'Leisure'
# Updated: 'Bucky's Butchery' → 'Food & Dining'
# Updated: 'Bridges Inc' → 'Housing & Utilities'
# Updated: 'ASO ELECTRICAL TRADING SDN BHD' → 'Transportation'
# Updated: 'CANADIAN TIRE 235' → 'Transportation'
# Updated: 'MR. D.I.Y. (KUCHAI) SDN BHD' → 'Transportation'
# Updated: 'MIAMI SCIENCE
# MUSEUM' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Paradise Restaurant' → 'Food & Dining'
# Updated: 'Juwita
# Weddings Sdn Bhd.' → 'Food & Dining'
# Updated: 'PappaRich BMC' → 'Leisure'
# Updated: 'Sunshine POS' → 'Leisure'
# Updated: 'OGN GROUP SDN BHD' → 'Food & Dining'
# Updated: 'First City Parking Sdn Bhd' → 'Transportation'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'Casablanca Cafe and Bogart's
# Bar' → 'Food & Dining'
# Updated: 'Golden
# Opear' → 'Leisure'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'Panda Express' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Hernandez, Brown and Rodriguez' → 'Housing & Utilities'
# Updated: 'White Group' → 'Leisure'
# Updated: 'Buckley's on Queen Anne' → 'Personal Care & Education'
# Updated: 'RESTORAN WAN SHF' → 'Leisure'
# Updated: 'CARREFOUR' → 'Leisure'
# Updated: 'Aneka Intertrade Marketing Sdn Bhd' → 'Transportation'
# Updated: 'Shell' → 'Transportation'
# Updated: 'Willy McCoy's' → 'Transportation'
# Updated: 'GAUD2' → 'Transportation'
# Updated: 'BEMED (SP) SDN. BHZ.' → 'Transportation'
# Updated: 'LIAN HING STATIONERY SDN BHD' → 'Transportation'
# Updated: 'Parker LLC' → 'Leisure'
# Updated: 'THREE STOOGES' → 'Leisure'
# Updated: 'OLIVE GARDEN 1184' → 'Food & Dining'
# Updated: 'Arnold, Mercer and Shelton' → 'Housing & Utilities'
# Updated: 'POPULAR BOOK' → 'Leisure'
# Updated: 'Bennett, Sullivan and Collier' → 'Food & Dining'
# Updated: 'McDonald's Shell Mahkota Cheras DT' → 'Food & Dining'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'MOONSTAR RESTAURANT' → 'Food & Dining'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'PASARAYA JALAL SDN BHD' → 'Transportation'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'LIM SENG THO HARDWARE TRADING' → 'Transportation'
# Updated: 'SHOPPERS' → 'Transportation'
# Updated: 'JOHNNY ROCKETS' → 'Transportation'
# Updated: 'The Cut Steakhouse &Burgers' → 'Food & Dining'
# Updated: 'RED LOBSTER 0620' → 'Food & Dining'
# Updated: 'SCALINI
# RESTAURANT' → 'Food & Dining'
# Updated: 'ADRAK' → 'Leisure'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'SURATI FARSAN MART' → 'Food & Dining'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'SHAKE SHACK' → 'Food & Dining'
# Updated: 'KT WONG TRADING' → 'Transportation'
# Updated: 'SO GONG DONG TOFU HOUSE' → 'Housing & Utilities'
# Updated: 'PINGHWAI TRADING SDN BHD' → 'Transportation'
# Updated: 'Berghotel
# Grosse Scheidegg' → 'Leisure'
# Updated: 'CHILE'S TEXAS GRELL' → 'Food & Dining'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'KEDAI PAPAN YEW CHUAN' → 'Food & Dining'
# Updated: 'TAQUERIA GUADALAJARA' → 'Transportation'
# Updated: '<P/' → 'Leisure'
# Updated: 'Perry, Brown and Hudson' → 'Housing & Utilities'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'KEDAI PAPAN YEW CHUAN' → 'Food & Dining'
# Updated: 'B & BEST RESTAURANT' → 'Food & Dining'
# Updated: 'GEETHA RESTAURANT' → 'Food & Dining'
# Updated: 'HARBOR FREIGHT TOOLS' → 'Transportation'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'Henderson, Baker and Johnson' → 'Food & Dining'
# Updated: 'McDonald's Pioneer Mall' → 'Food & Dining'
# Updated: 'KING
# Sooberla' → 'Personal Care & Education'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Dixon, Hall and Payne' → 'Food & Dining'
# Updated: 'Segi Cash & Carry Sdn.Bhd' → 'Transportation'
# Updated: 'Derbang Alaf Restaurants Sdn Bhd' → 'Food & Dining'
# Updated: 'FIVE GUYS' → 'Transportation'
# Updated: 'Walmart' → 'Food & Dining'
# Updated: 'Gallagher PLC' → 'Leisure'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Sam's Club' → 'Food & Dining'
# Updated: 'AEON CO. (M) BHD' → 'Leisure'
# Updated: 'Matthews-Roman' → 'Leisure'
# Updated: 'Campbell-Weiss' → 'Transportation'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'SUKHOTHAI SUSHI + ASIAN
# FUSION' → 'Food & Dining'
# Updated: 'Berghotel
# Grosse Scheidegg' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Williams and Sons
# Medina-Kennedy' → 'Personal Care & Education'
# Updated: 'Jackson-Oliver' → 'Transportation'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'HIGH FIVE ENTERPRISE' → 'Leisure'
# Updated: 'Shang
# Thai-' → 'Food & Dining'
# Updated: 'Faulkner Group
# Mendoza-Scott' → 'Housing & Utilities'
# Updated: 'TEO HENG STATIONERY & BOOKS' → 'Food & Dining'
# Updated: 'Harvey-Rivas' → 'Transportation'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'Mcdonald and Sons' → 'Food & Dining'
# Updated: 'Aur
# e Anne's' → 'Food & Dining'
# Updated: 'WAL-MART®' → 'Food & Dining'
# Updated: 'IDEAL MENU GROUP SDN BHD' → 'Food & Dining'
# Updated: 'YIN MA (M) SDN.BHD.' → 'Personal Care & Education'
# Updated: 'None' → 'Uncategorized'
# Updated: 'DAIKO' → 'Leisure'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'Angelis' → 'Leisure'
# Updated: 'RISTORANTE CIAO BELLA' → 'Leisure'
# Updated: 'Japengo
# Café' → 'Food & Dining'
# Updated: 'Morgan, Moss and Bush
# Robinson-Martin' → 'Food & Dining'
# Updated: 'G.W.P. LLC' → 'Leisure'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'KING'S CONFECTIONERY S/B 273500-U (JJ)' → 'Food & Dining'
# Updated: 'Holland, Griffin and Coleman' → 'Food & Dining'
# Updated: '(P.)' → 'Leisure'
# Updated: 'ROSS' → 'Transportation'
# Updated: 'SUBWAY' → 'Transportation'
# Updated: 'KAY JEWELERS' → 'Food & Dining'
# Updated: 'Price-Bishop' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'None' → 'Uncategorized'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Juniper & Ivy' → 'Housing & Utilities'
# Updated: 'Williams Group' → 'Leisure'
# Updated: 'Carl's Fr.' → 'Food & Dining'
# Updated: 'LATITUDE 31' → 'Leisure'
# Updated: 'THE SMD STORE' → 'Food & Dining'
# Updated: 'SPEEDWAY' → 'Leisure'
# Updated: 'BEYOND BROTHERS HARDWARE' → 'Transportation'
# Updated: 'FISH' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'DOMINO'S PIZZA SEGAMBUT' → 'Food & Dining'
# Updated: 'FLYING J
# TRAVEL PLAZA' → 'Transportation'
# Updated: 'BED BATH & BEYOND' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'GOLDEN KEY MAKER' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'GRUPO EMPORIO CASIDI S.L' → 'Leisure'
# Updated: 'SABOTEN' → 'Leisure'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'Walmart' → 'Food & Dining'
# Updated: 'Barber LLC' → 'Housing & Utilities'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'FTOF NOODLE HOUSE' → 'Housing & Utilities'
# Updated: 'La Baguette Bar &
# Grill' → 'Food & Dining'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'MR. D.1.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'UNICO AUTO DETAILING' → 'Housing & Utilities'
# Updated: 'Starbucks Coffee' → 'Transportation'
# Updated: 'Sala
# Intom' → 'Leisure'
# Updated: 'Restaurant McDonald's Versailles Manege' → 'Food & Dining'
# Updated: 'tando's Queunsbay Mall' → 'Food & Dining'
# Updated: 'Rosebud on Rush' → 'Housing & Utilities'
# Updated: 'TONY ROMA'S AEON TEBRAU CITY' → 'Leisure'
# Updated: 'AMANO MALAYSIA SDN BHD' → 'Transportation'
# Updated: 'Bar Louie Huntsville!' → 'Food & Dining'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'Roberson and Sons' → 'Housing & Utilities'
# Updated: 'New York Bagel' → 'Food & Dining'
# Updated: 'ANY RESTAURANT' → 'Food & Dining'
# Updated: 'Tiendas Comercial Mexicana S.A. de C.V.' → 'Food & Dining'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'WEIGELS' → 'Transportation'
# Updated: 'THE ALLEY
# AMSTERDAM' → 'Food & Dining'
# Updated: 'Lynnwood' → 'Housing & Utilities'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'BREWERY TAP' → 'Food & Dining'
# Updated: 'Guardian Health And Beauty Sdn Bhd' → 'Personal Care & Education'
# Updated: 'tibits Restaurant Bar Food to go' → 'Food & Dining'
# Updated: 'MONSIEUR ( M ) SDN. BHD.' → 'Transportation'
# Updated: 'Kiwiana Restaurant' → 'Food & Dining'
# Updated: 'LA CANASTA' → 'Leisure'
# Updated: 'BAKALIMA SDN BHD' → 'Transportation'
# Updated: 'la
# aie' → 'Leisure'
# Updated: 'AEON CO. (M) BHD' → 'Leisure'
# Updated: 'FUDDRUCKERS' → 'Leisure'
# Updated: 'Levy and Arnold
# Jenkins-Lewis' → 'Housing & Utilities'
# Updated: 'Carl's Jr' → 'Food & Dining'
# Updated: 'HAPPY TIMES LTD' → 'Leisure'
# Updated: 'KEDAI PAPAN YEW CHUAN' → 'Food & Dining'
# Updated: 'HMSHOST' → 'Leisure'
# Updated: 'KABUKI' → 'Transportation'
# Updated: 'BJ'S IRVINE' → 'Food & Dining'
# Updated: 'JENERIS by Abren' → 'Food & Dining'
# Updated: 'Secret Recipe' → 'Food & Dining'
# Updated: 'USA GASOLINE' → 'Transportation'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'ENW Hardware Centre (M) Sdn. Bhd.' → 'Transportation'
# Updated: 'TECK KEE (2012) CHICKEN RICE PTE LTD' → 'Food & Dining'
# Updated: 'Chal Midtown West' → 'Housing & Utilities'
# Updated: 'SWC ENTERPRISE SDN BHD' → 'Transportation'
# Updated: 'SHOTS' → 'Transportation'
# Updated: 'Thai Thai Restaurant' → 'Food & Dining'
# Updated: 'ROSS' → 'Transportation'
# Updated: 'BEMED (SP) SDN. BHD.' → 'Transportation'
# Updated: 'HONEYMEE (GARDENA)' → 'Food & Dining'
# Updated: 'Restaurant Breda' → 'Food & Dining'
# Updated: 'KARAM BEIRUT' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'KEDAI PAPAN YEW CHUAN' → 'Food & Dining'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'THE STORE (MALAYSIA) SDN. BHD.' → 'Transportation'
# Updated: 'MAC'S
# STEAK
# ROUGH' → 'Food & Dining'
# Updated: 'Carney-Rogers' → 'Transportation'
# Updated: 'Hudana Trading LLC' → 'Transportation'
# Updated: 'ENW Hardware Centre (M) Sdn. 3hd.' → 'Transportation'
# Updated: 'Bar Rua' → 'Leisure'
# Updated: 'Mccormick and Sons' → 'Food & Dining'
# Updated: 'AIK HUAT HARDWARE
# ENTERPRISE (SETIA
# ALAM) SON BHU' → 'Personal Care & Education'
# Updated: 'Maple Leaf Restaurant, Jumeirah' → 'Food & Dining'
# Updated: 'VIJ'S RANGOLI' → 'Transportation'
# Updated: 'NIKE Factory Store' → 'Leisure'
# Updated: 'Decker, Miller and Hall' → 'Housing & Utilities'
# Updated: 'ALDI' → 'Housing & Utilities'
# Updated: 'Watson-Harris
# Castillo-Obrien' → 'Transportation'
# Updated: 'FARMASI LIGAMAS' → 'Leisure'
# Updated: 'Car Spa' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Chili's' → 'Food & Dining'
# Updated: 'PJ'S PET EXPRESS' → 'Transportation'
# Updated: 'POPULAR BOOK' → 'Leisure'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'Hale LLC' → 'Housing & Utilities'
# Updated: 'TACO SHOP' → 'Food & Dining'
# Updated: 'SUPREME LA' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'None' → 'Uncategorized'
# Updated: 'El Valle' → 'Transportation'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'HP Pho Ga' → 'Transportation'
# Updated: 'Meyer-Ramirez' → 'Transportation'
# Updated: '21 Club' → 'Leisure'
# Updated: 'MR. D.I.Y. (KUCHAI) SDN BHD' → 'Transportation'
# Updated: 'zuma' → 'Transportation'
# Updated: 'The Colony' → 'Leisure'
# Updated: 'Q-PARK (NI) LTD' → 'Leisure'
# Updated: 'Dartrigo Motion Hospitality Cial' → 'Leisure'
# Updated: 'GL HANDICRAFT & TAILORING' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'FUYI MINI MARKET' → 'Leisure'
# Updated: 'YONG CEN ENTERPRISE' → 'Transportation'
# Updated: 'VERIZON WIRELESS' → 'Transportation'
# Updated: 'LEVANT Restaurant' → 'Food & Dining'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'MACE RESTAURANT' → 'Food & Dining'
# Updated: 'Whitaker, Gray and Green' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'IHOP' → 'Food & Dining'
# Updated: 'Johnson-Higgins
# Macdonald-Hampton' → 'Food & Dining'
# Updated: 'USA' → 'Transportation'
# Updated: 'EL POLLO LOCO' → 'Leisure'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'Manila' → 'Leisure'
# Updated: 'Pizza Hut Restaurant Sdn. Bhd.' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'THREE STOOGES' → 'Leisure'
# ...
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'Segi Cash & Carry Sdn.Bhd' → 'Transportation'
# Updated: 'HON HWA HARDWARE TRADING' → 'Transportation'
# Updated: 'Transmetropolitan' → 'Transportation'
# Updated: 'DOUBLE AA CORP FUELS' → 'Transportation'
# Updated: 'POPPIES' → 'Housing & Utilities'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'ONE ONE THREE SEAFOOD RESTAURANT SDN BHD' → 'Food & Dining'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'DOMINO'S PIZZA SEGAMBUT' → 'Food & Dining'
# Updated: 'Cee Fine Thai' → 'Food & Dining'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'Reilly, Hicks and Hughes' → 'Housing & Utilities'
# Updated: 'None' → 'Uncategorized'
# Updated: 'POTAMOS LIOPETRIOY' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'THAI DELICIOUS RESTAURANT' → 'Food & Dining'
# Updated: 'TWISTED ROOT BURGER CO. - RICHARDSON' → 'Housing & Utilities'
# Updated: 'CAFFE' TORINO' → 'Transportation'
# Updated: 'Marco Pierre White' → 'Leisure'
# Updated: 'CROSS CHANNEL NETWORK SDN. BHD.' → 'Transportation'
# Updated: 'Carmichael CarWash' → 'Personal Care & Education'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'Barnett-Hughes' → 'Housing & Utilities'
# Updated: 'None' → 'Uncategorized'
# Updated: 'BEIJING EXPRESS' → 'Transportation'
# Updated: 'Walgreens' → 'Personal Care & Education'
# Updated: 'Hughes-Jones' → 'Housing & Utilities'
# Updated: 'EDEN IMPRESSION SDN BHD' → 'Leisure'
# Updated: 'Curious Palette' → 'Leisure'
# Updated: 'CURRY-YA MALAGA SL' → 'Food & Dining'
# Updated: 'Lewis Group' → 'Transportation'
# Updated: 'AA PHARMACY' → 'Personal Care & Education'
# Updated: 'Adams and Sons' → 'Leisure'
# Updated: 'LURE
# FISH HOUSE' → 'Housing & Utilities'
# Updated: 'None' → 'Uncategorized'
# Updated: 'THE
# HOME
# DEPOT
# ®' → 'Housing & Utilities'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Restaurant
# Mundart' → 'Food & Dining'
# Updated: 'Cracker Barrel' → 'Food & Dining'
# Updated: '7-ELEVEN' → 'Food & Dining'
# Updated: 'Nando's' → 'Food & Dining'
# Updated: 'Cooley Ltd' → 'Leisure'
# Updated: 'Gresecake Factory' → 'Food & Dining'
# Updated: 'SAM SAM TRADING CO' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'TRI SHAAS SDN BHD' → 'Food & Dining'
# Updated: 'THE SEA
# Fish & Chips' → 'Food & Dining'
# Updated: 'bugis' → 'Leisure'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'Konoba-Pizzeria
# "MASLINA"' → 'Food & Dining'
# Updated: 'CHA FOR TEA' → 'Leisure'
# Updated: 'Pendo Chinese Restaurant' → 'Food & Dining'
# Updated: 'AEON CO. (M) BHD' → 'Leisure'
# Updated: 'Kaiseki' → 'Food & Dining'
# Updated: 'KAISON FURNISHING SDN BHD' → 'Food & Dining'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'Hudson-Calderon' → 'Transportation'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'CENTRAL PARK STEAK HOUSE' → 'Food & Dining'
# Updated: 'Aloha Pali' → 'Personal Care & Education'
# Updated: 'ILIO'S' → 'Transportation'
# Updated: 'BROTHERS
# FARMERS MKT' → 'Food & Dining'
# Updated: 'RESTORAN HWA MUI SUTERA SDN BHD' → 'Transportation'
# Updated: 'LIGHTROOM GALLERY SDN BHD' → 'Transportation'
# Updated: 'Peter Chang' → 'Transportation'
# Updated: 'Madronna Chevron' → 'Transportation'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE' → 'Food & Dining'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'Espinoza LLC' → 'Leisure'
# Updated: 'CiCi's Pizza' → 'Food & Dining'
# Updated: 'WHOLE
# FOODS' → 'Food & Dining'
# Updated: 'Hobbs Group' → 'Housing & Utilities'
# Updated: 'Martin Group' → 'Leisure'
# Updated: 'AEON CO. (M) BHD' → 'Leisure'
# Updated: 'BEST BUY' → 'Transportation'
# Updated: 'Framingham' → 'Housing & Utilities'
# Updated: 'MPH BOOKSTORES
# SDN BHD' → 'Food & Dining'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'Salazar PLC' → 'Housing & Utilities'
# Updated: 'Yam Fresh' → 'Leisure'
# Updated: 'HINTZELL's OYSTER VERRE' → 'Food & Dining'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'Walmart' → 'Food & Dining'
# Updated: 'Horton's The Steakhouse' → 'Food & Dining'
# Updated: 'Rexall' → 'Leisure'
# Updated: 'ALDI' → 'Housing & Utilities'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'AEON CO. (M) BHD' → 'Leisure'
# Updated: 'CIRCLE K VIETNAM' → 'Food & Dining'
# Updated: 'AREAS USA ORD, LLC.' → 'Housing & Utilities'
# Updated: '67 Pall Mall' → 'Housing & Utilities'
# Updated: 'Walmart' → 'Food & Dining'
# Updated: 'NIKKI BEACH' → 'Leisure'
# Updated: 'LIM SENG THO HARDWARE TRADING' → 'Transportation'
# Updated: 'XIN WANG' → 'Leisure'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Maxincome Resources Sdn Bhd' → 'Housing & Utilities'
# Updated: 'C Thrift Store' → 'Food & Dining'
# Updated: 'H&M' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'FUYI MINI MARKET' → 'Leisure'
# Updated: 'Jordan-Spencer' → 'Personal Care & Education'
# Updated: '(FUTURE RETAIL LTD)' → 'Transportation'
# Updated: 'Clean & Green Car Wash' → 'Personal Care & Education'
# Updated: 'Segi Cash & Carry Sdn. Bhd.' → 'Transportation'
# Updated: 'SUPER A FOODS' → 'Food & Dining'
# Updated: 'ARHAM RESTAURANT LLP' → 'Food & Dining'
# Updated: 'TIONG
# BAHRU
# BAKERY' → 'Food & Dining'
# Updated: 'Tian Tian Hainanese Chicken Rice' → 'Food & Dining'
# Updated: 'SHELL CANADA PRODUCTS' → 'Housing & Utilities'
# Updated: 'Kiwiana Restaurant' → 'Food & Dining'
# Updated: 'Burke-Gordon' → 'Transportation'
# Updated: 'PRINT EXPERT SDN BHD' → 'Food & Dining'
# Updated: 'Walmart' → 'Food & Dining'
# Updated: 'IKEA FOOD' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Walgreens' → 'Personal Care & Education'
# Updated: 'MOONLIGHT CAKE HOUSE SDN BHD' → 'Food & Dining'
# Updated: 'Hotel Okura Amsterdam' → 'Leisure'
# Updated: 'Texas Chicken' → 'Food & Dining'
# Updated: 'Bubba Gump Shrimp Co' → 'Food & Dining'
# Updated: 'Collector's Choice Restaurant' → 'Food & Dining'
# Updated: 'MY HAPPY PHARMACY PLT' → 'Personal Care & Education'
# Updated: 'Olive C
# Garder' → 'Food & Dining'
# Updated: 'Sheetz' → 'Leisure'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'FELLINI KROGER' → 'Food & Dining'
# Updated: 'TARGET' → 'Transportation'
# Updated: 'III GUYS RESTAURANT
# & SPORTS BAR' → 'Food & Dining'
# Updated: 'Hutchinson PLC' → 'Housing & Utilities'
# Updated: 'None' → 'Uncategorized'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'Papalote Taco House' → 'Housing & Utilities'
# Updated: 'Arby's Roast Beef' → 'Food & Dining'
# Updated: 'KEDAI UBAT & RUNCIT HONG
# NING SDN. BHD.' → 'Transportation'
# Updated: 'Hines Ltd' → 'Transportation'
# Updated: 'ADVANCO COMPANY' → 'Housing & Utilities'
# Updated: 'PAPPADEAU' → 'Food & Dining'
# Updated: 'TED HENG STATIONERY & BOOKS' → 'Leisure'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'La Aventura' → 'Leisure'
# Updated: 'THE HOME DEPOT' → 'Housing & Utilities'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'KFA SUPPLY' → 'Transportation'
# Updated: 'East of Málaga' → 'Leisure'
# Updated: 'Guardian Health And Beauty Sdn Bhd' → 'Personal Care & Education'
# Updated: 'AEON CO. (M) BHD.' → 'Leisure'
# Updated: 'Subway#2457-0' → 'Transportation'
# Updated: 'KEDAI UBAT & RUNCIT HONG
# NING SDN. BHD.' → 'Transportation'
# Updated: 'Subway.' → 'Transportation'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'AMANO MALAYSIA SON BHD' → 'Personal Care & Education'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'WAWAWA' → 'Food & Dining'
# Updated: 'MEI LET RESTAURANT' → 'Food & Dining'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'Baker-Wagner' → 'Food & Dining'
# Updated: 'YONG SOON FATT S/B (81497-P)' → 'Transportation'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'Browns Covent Gardens' → 'Food & Dining'
# Updated: 'The Shawarma Factory' → 'Leisure'
# Updated: 'STAPLES' → 'Housing & Utilities'
# Updated: 'INTERNATIONAL DUITA' → 'Leisure'
# Updated: 'David-Rhodes' → 'Leisure'
# Updated: 'FY EAGLE ENTERPRISE' → 'Transportation'
# Updated: 'KOHL'S' → 'Food & Dining'
# Updated: 'CAFE MATISSE' → 'Food & Dining'
# Updated: 'JAWED HABIB' → 'Leisure'
# Updated: 'TGIF DUBAI MALL' → 'Leisure'
# Updated: 'Hays and Sons' → 'Housing & Utilities'
# Updated: 'Fatboy's
# Burger Bar' → 'Food & Dining'
# Updated: 'IN-N-OUT BURGER GRANTS PASS' → 'Housing & Utilities'
# Updated: 'Kirk-Green' → 'Transportation'
# Updated: 'PASARAYA
# BORONG PINTAR SDN BHD' → 'Transportation'
# Updated: 'KEDAI PAPAN YEW CHUAN' → 'Food & Dining'
# Updated: 'SINNATHAMBY HOLDINGS SDN. BHD.' → 'Leisure'
# Updated: 'Peterson-Bryant' → 'Personal Care & Education'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'Rhodes, Young and Yoder' → 'Leisure'
# Updated: 'Tails in the City' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'ZEN AYRIS s.n.c.' → 'Personal Care & Education'
# Updated: 'ALDI STORES' → 'Housing & Utilities'
# Updated: 'SANYO STATIONERY SHOP' → 'Food & Dining'
# Updated: 'DARTMOUTH BOOKSTORE, INC.' → 'Food & Dining'
# Updated: 'AMTECH ELECTRICAL SUPPLIES' → 'Transportation'
# Updated: 'KEDAI PAPAN YEW CHUAN' → 'Food & Dining'
# Updated: 'B & BEST RESTAURANT' → 'Food & Dining'
# Updated: 'JALISCO' → 'Transportation'
# Updated: 'None' → 'Uncategorized'
# Updated: 'TARGET' → 'Transportation'
# Updated: 'Taylor Ltd' → 'Housing & Utilities'
# Updated: 'Gaines' → 'Housing & Utilities'
# Updated: 'Reynolds PLC' → 'Transportation'
# Updated: '99 Restaurant & Pub' → 'Food & Dining'
# Updated: 'CHEF HENRY RIBS HOUSE' → 'Food & Dining'
# Updated: 'Nixon-Delacruz' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Rintre De' → 'Leisure'
# Updated: 'COLUMBUS RESTAURANT' → 'Food & Dining'
# Updated: 'Shell ISNI PETRO TRADING' → 'Transportation'
# Updated: 'La Banca' → 'Food & Dining'
# Updated: 'Mccullough-Bradley' → 'Housing & Utilities'
# Updated: 'RESTORAN WAN SHENG' → 'Leisure'
# Updated: 'Hamburger Mary's' → 'Food & Dining'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'Weaver Ltd' → 'Housing & Utilities'
# Updated: 'Mckenzie PLC' → 'Housing & Utilities'
# Updated: 'BK SOUL FOOD & CATERING' → 'Food & Dining'
# Updated: 'IN-N-OUT BURGER SANTA CLARA' → 'Food & Dining'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'BEST BUY' → 'Transportation'
# Updated: 'shutterstock' → 'Leisure'
# Updated: 'SAFEWAY' → 'Transportation'
# Updated: 'KFC Cape Hill DT' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'tealive' → 'Leisure'
# Updated: 'Nick's Tuscan Grill' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'BLOOMTHODALE'S. NEWPORT BEACH' → 'Food & Dining'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'Fowler-Griffin' → 'Housing & Utilities'
# Updated: 'Little Delhi' → 'Food & Dining'
# Updated: 'Shell' → 'Transportation'
# Updated: '99 SPEED MART S/B' → 'Transportation'
# Updated: 'ROSS' → 'Transportation'
# Updated: 'The Rose Club' → 'Leisure'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'KFC SALAK TINGGI' → 'Food & Dining'
# Updated: 'ONE ONE THREE SEAFOOD RESTAURANT SDN BHD' → 'Food & Dining'
# Updated: 'GARDENIA BAKERIES (KL) SDN BHD' → 'Food & Dining'
# Updated: 'MR. D.I.Y. (M) SDN BHD' → 'Transportation'
# Updated: 'MR. D.I.Y. (KUCHAI) SDN BHD' → 'Transportation'
# Updated: 'AEON CO. (M) BHD' → 'Leisure'
# Updated: 'KEDAI RUNCIT ZBH' → 'Leisure'
# Updated: 'CROSS CHANNEL NETWORK SDN. BHD.' → 'Transportation'
# Updated: 'S.H.H. MOTOR ( SUNGAI RENGIT ) SDN. BHD.' → 'Transportation'
# Updated: 'LIAN CHI PU TIAN VEGETARIAN
# RESTAURANT SDN BHD' → 'Food & Dining'
# Updated: 'Finnegan's' → 'Food & Dining'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'IHOP' → 'Food & Dining'
# Updated: 'Perez Group' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'AUSTRALIA POST' → 'Transportation'
# Updated: 'WESTERN 'EASTERN'
# STATIONERY SDN. BHD' → 'Transportation'
# Updated: 'Pizza Hut India' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'BOMBAY BARBEQUE' → 'Food & Dining'
# Updated: 'West PLC' → 'Housing & Utilities'
# Updated: 'TANJONGMAS BOOKCENTRE (PJ) SDN BHD' → 'Food & Dining'
# Updated: 'Rogers, James and Hansen' → 'Housing & Utilities'
# Updated: 'Cafe Eugene' → 'Food & Dining'
# Updated: 'PizzaExpress' → 'Food & Dining'
# Updated: 'TRADER JOE'S' → 'Food & Dining'
# Updated: 'Apple Retail Netherlands B.V.' → 'Food & Dining'
# Updated: 'GORDON RAMSAY' → 'Food & Dining'
# Updated: 'St.George Apartmanház Kft.' → 'Leisure'
# Updated: 'KEDAI PAPAN YEW CHUAN' → 'Food & Dining'
# Updated: 'JACK IN THE BOX.' → 'Transportation'
# Updated: 'Scott LLC' → 'Transportation'
# Updated: 'Byrd Group' → 'Leisure'
# Updated: 'CLEAN MACHINE DATY
# DETAIL CENTER' → 'Food & Dining'
# Updated: 'Natomas Car Wash & Detail' → 'Housing & Utilities'
# Updated: 'Tran PLC' → 'Transportation'
# Updated: 'GEMINI NJAM d. o. o.' → 'Personal Care & Education'
# Updated: 'McDonald's.' → 'Food & Dining'
# Updated: 'REBler GnbH & Co KG' → 'Food & Dining'
# Updated: 'COLUMBUS RESTAURANT' → 'Food & Dining'
# Updated: 'ZNK Foods & Beverages Pvt. Ltd.' → 'Food & Dining'
# Updated: '$9 SPEED MART S/D (519537.X)' → 'Transportation'
# Updated: 'SIGDI RESTAURANT' → 'Food & Dining'
# Updated: 'KING'S CONFECTIONERY S/B 273500-U' → 'Food & Dining'
# Updated: 'KING'S CONFECTIONERY
# (KSB)' → 'Food & Dining'
# Updated: 'None' → 'Uncategorized'
# Updated: 'None' → 'Uncategorized'
# Updated: 'Farmasi Maluri S/B(587969-U)' → 'Housing & Utilities'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'STARBUCKS' → 'Food & Dining'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'STAPLES' → 'Housing & Utilities'
# Updated: 'Haveli Restaurant' → 'Food & Dining'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'RESTORAN
# WEI KEE' → 'Leisure'
# Updated: 'Crawford, Acosta and Solomon' → 'Housing & Utilities'
# Updated: 'THE COFFEE BEAN
# & TEA LEAF (M) SDN. BHD.
# outing' → 'Food & Dining'
# Updated: 'UNIPHARM PHARMACY' → 'Leisure'
# Updated: 'MAKASSAR FRESH MARKET SDN BHD' → 'Food & Dining'
# Updated: 'tan woon yann' → 'Leisure'
# Updated: 'Phillips PLC' → 'Housing & Utilities'
# Updated: 'Parker-Gonzalez' → 'Housing & Utilities'
# Updated: 'None' → 'Uncategorized'
# Updated: 'The Noodle House' → 'Food & Dining'
# Updated: 'CHLOE81' → 'Personal Care & Education'
# Updated: 'Firefly American Bistro' → 'Food & Dining'
# Updated: 'ANN GIAP TRADING SDN BHD' → 'Transportation'
# Updated: 'SYARIKAT PERNIAGAAN GIN KEE
# (81109-A)' → 'Personal Care & Education'
# Updated: 'AIK HUAT HARDWARE
# ENTERPRISE (SETIA
# ALAM) SDN BHD' → 'Food & Dining'
# Updated: 'CHURCH'S
# CHICKEN' → 'Food & Dining'
# Updated: 'IKEA FOOD' → 'Food & Dining'
# Updated: 'ROYAL FARMS' → 'Leisure'
# Updated: 'SUN WONG KUT SDN BHD' → 'Transportation'
# Updated: 'MASA' → 'Transportation'
# Updated: 'Gerbang Alaf Restaurants Sdn Bhd' → 'Food & Dining'
# Updated: 'KEBAB HOUSE' → 'Food & Dining'
# Updated: 'PROSPER NIAGA' → 'Personal Care & Education'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'YHM Aeon Tebrau City' → 'Leisure'
# Updated: 'None' → 'Uncategorized'
# Updated: 'LANDFALL RESTAURANT' → 'Food & Dining'
# Updated: 'RINCON MEXICANO' → 'Food & Dining'
# Updated: 'Deli In The Park' → 'Leisure'
# Updated: 'LIDL' → 'Food & Dining'
# Updated: 'UNIHAKKA INTERNATIONAL SDN BHD' → 'Transportation'
# Updated: 'Walmart' → 'Food & Dining'
# Updated: 'SIZE?' → 'Food & Dining'
# Updated: 'SM CENTERPOINT BLOG.' → 'Personal Care & Education'
# Updated: 'Subway Sandwiches & Salads' → 'Food & Dining'
# Updated: 'San Carlos - Ducky's Car Wash' → 'Housing & Utilities'
# Updated: 'MAGIC MOUNTAIN' → 'Leisure'
# Updated: 'LIGHTROOM GALLERY SDN BHD' → 'Transportation'
