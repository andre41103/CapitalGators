# %%
# import os
# import time
# def rename_images(input_dir):
#     if not os.path.exists(input_dir):
#         print(f"Directory '{input_dir}' does not exist.")
#         return
#     image_files = sorted([f for f in os.listdir(input_dir) if f.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'gif'))])
#     for idx, filename in enumerate(image_files, start=1):
#         ext = os.path.splitext(filename)[1]  # Get file extension
#         new_name = f"receipt_{idx}{ext}"
#         old_path = os.path.join(input_dir, filename)
#         new_path = os.path.join(input_dir, new_name)
#         # Handle permission error and ensure unique filenames
#         attempt = 1
#         while os.path.exists(new_path):
#             new_name = f"receipt_{idx}_v{attempt}{ext}"
#             new_path = os.path.join(input_dir, new_name)
#             attempt += 1
#         try:
#             os.rename(old_path, new_path)
#             print(f"Renamed '{filename}' to '{new_name}'")
#         except PermissionError:
#             print(f"Skipping '{filename}' due to permission error.")
# # Directory containing receipt images
# input_dir = "big_receipt_dataset"
# rename_images(input_dir)

# %%
import os
import json
import re
from azure.core.credentials import AzureKeyCredential
from azure.ai.documentintelligence import DocumentIntelligenceClient
from PIL import Image

# Set up your Azure AI Document Intelligence credentials
endpoint = "https://resourceforimages.cognitiveservices.azure.com/"  # Replace with your endpoint
key = "FcpM8ICO9uWjpqUZjGMjcgu3TcBg363FsUTF2LhpObr4SAfJa3ngJQQJ99BCACYeBjFXJ3w3AAALACOGgWZc"  # Replace with your key

# Directory containing receipt images
input_dir = "big_receipt_dataset"
# Directory to store JSON output
output_dir = "processed_json_images"

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Initialize the client
document_intelligence_client = DocumentIntelligenceClient(
    endpoint=endpoint, credential=AzureKeyCredential(key)
)

# Function to extract the numeric part of filenames
def extract_number(filename):
    match = re.search(r"(\d+)", filename)  # Extract first number in filename
    return int(match.group(1)) if match else float('inf')  # Convert to int or set to infinity if no number found

# Function to serialize date objects
def serialize_date(date_obj):
    return date_obj.strftime("%Y-%m-%d") if date_obj else None

# Function to safely get a value from a field
def get_field_value(field, field_type="string"):
    if field:
        if field_type == "string":
            return field.value_string if field.value_string else None
        elif field_type == "date":
            return serialize_date(field.value_date) if field.value_date else None
        elif field_type == "currency":
            return field.value_currency.amount if field.value_currency else None
        elif field_type == "number":
            return field.value_number if field.value_number else None
    return None

# Function to resize the image if it's too large
def resize_image(image_path, max_size=(800, 800), max_quality=85):
    with Image.open(image_path) as img:
        print(f"Original image size: {os.path.getsize(image_path) / (1024 * 1024):.2f} MB")
        img.thumbnail(max_size)
        resized_image_path = os.path.splitext(image_path)[0] + "_resized.jpg"
        img.save(resized_image_path, "JPEG", quality=max_quality)
        print(f"Resized image size: {os.path.getsize(resized_image_path) / (1024 * 1024):.2f} MB")
    return resized_image_path

# Function to process a batch of receipts
def process_receipt_batch(batch):
    for filename in batch:
        file_path = os.path.join(input_dir, filename)
        if not filename.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp', '.pdf')):
            continue

        print(f"Processing: {filename}")
        file_size = os.path.getsize(file_path)
        print(f"Size: {file_size / (1024 * 1024):.2f} MB")

        if file_size > 4 * 1024 * 1024:
            print(f"Resizing {filename}...")
            file_path = resize_image(file_path)

        with open(file_path, "rb") as receipt_file:
            poller = document_intelligence_client.begin_analyze_document("prebuilt-receipt", receipt_file)
            receipts = poller.result()

        receipt_data = []
        for idx, receipt in enumerate(receipts.documents):
            receipt_info = {
                "receipt_number": idx + 1,
                "receipt_type": receipt.doc_type,
                "merchant_name": get_field_value(receipt.fields.get("MerchantName")),
                "transaction_date": get_field_value(receipt.fields.get("TransactionDate"), "date"),
                "items": []
            }
            if receipt.fields.get("Items"):
                for item in receipt.fields.get("Items").value_array:
                    receipt_info["items"].append({
                        "description": get_field_value(item.value_object.get("Description")),
                        "quantity": get_field_value(item.value_object.get("Quantity"), "number"),
                        "price": get_field_value(item.value_object.get("Price"), "currency"),
                        "total_price": get_field_value(item.value_object.get("TotalPrice"), "currency")
                    })
            receipt_info["subtotal"] = get_field_value(receipt.fields.get("Subtotal"), "currency")
            receipt_info["tax"] = get_field_value(receipt.fields.get("TotalTax"), "currency")
            receipt_info["tip"] = get_field_value(receipt.fields.get("Tip"), "currency")
            receipt_info["total"] = get_field_value(receipt.fields.get("Total"), "currency")
            receipt_data.append(receipt_info)

        receipt_json = json.dumps(receipt_data, indent=4)
        output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}.json")
        with open(output_path, "w") as json_file:
            json_file.write(receipt_json)

        print(f"Saved: {output_path}")

# Get all filenames and sort them numerically
all_filenames = sorted(
    [f for f in os.listdir(input_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp', '.pdf'))],
    key=extract_number  # Sort using extracted numeric value
)

### MANUALLY CHANGE THESE VALUES BEFORE EACH RUN ###
start_index = 2295   # Change this to select the batch you want to process
end_index = 3446    # Change this to start + 20 for the next batch

batch = all_filenames[start_index:end_index]
print(f"Processing {len(batch)} receipts from index {start_index} to {end_index - 1}...")
process_receipt_batch(batch)

print("Processing complete! 🎉")
# Out:
# Processing 1151 receipts from index 2295 to 3445...
# Processing: receipt_2296.jpg
# Size: 0.08 MB
# Saved: processed_json_images/receipt_2296.json
# Processing: receipt_2297.jpg
# Size: 0.12 MB
# Saved: processed_json_images/receipt_2297.json
# Processing: receipt_2298.jpg
# Size: 0.09 MB
# Saved: processed_json_images/receipt_2298.json
# Processing: receipt_2299.jpg
# Size: 0.10 MB
# Saved: processed_json_images/receipt_2299.json
# Processing: receipt_2300.jpg
# Size: 0.11 MB
# Saved: processed_json_images/receipt_2300.json
# Processing: receipt_2301.jpg
# Size: 0.15 MB
# Saved: processed_json_images/receipt_2301.json
# Processing: receipt_2302.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2302.json
# Processing: receipt_2303.jpg
# Size: 0.20 MB
# Saved: processed_json_images/receipt_2303.json
# Processing: receipt_2304.jpg
# Size: 0.12 MB
# Saved: processed_json_images/receipt_2304.json
# Processing: receipt_2305.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2305.json
# Processing: receipt_2306.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2306.json
# Processing: receipt_2307.jpg
# Size: 0.40 MB
# Saved: processed_json_images/receipt_2307.json
# Processing: receipt_2308.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2308.json
# Processing: receipt_2309.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2309.json
# Processing: receipt_2310.jpg
# Size: 0.45 MB
# Saved: processed_json_images/receipt_2310.json
# Processing: receipt_2311.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_2311.json
# Processing: receipt_2312.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2312.json
# Processing: receipt_2313.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2313.json
# Processing: receipt_2314.jpg
# Size: 0.65 MB
# Saved: processed_json_images/receipt_2314.json
# Processing: receipt_2315.jpg
# Size: 0.76 MB
# Saved: processed_json_images/receipt_2315.json
# Processing: receipt_2316.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2316.json
# Processing: receipt_2317.jpg
# Size: 0.85 MB
# Saved: processed_json_images/receipt_2317.json
# Processing: receipt_2318.jpg
# Size: 0.53 MB
# Saved: processed_json_images/receipt_2318.json
# Processing: receipt_2319.jpg
# Size: 0.52 MB
# Saved: processed_json_images/receipt_2319.json
# Processing: receipt_2320.jpg
# Size: 0.74 MB
# Saved: processed_json_images/receipt_2320.json
# Processing: receipt_2321.jpg
# Size: 0.16 MB
# Saved: processed_json_images/receipt_2321.json
# Processing: receipt_2322.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2322.json
# Processing: receipt_2323.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2323.json
# Processing: receipt_2324.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2324.json
# Processing: receipt_2325.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2325.json
# Processing: receipt_2326.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2326.json
# Processing: receipt_2327.jpg
# Size: 0.69 MB
# Saved: processed_json_images/receipt_2327.json
# Processing: receipt_2328.jpg
# Size: 0.69 MB
# Saved: processed_json_images/receipt_2328.json
# Processing: receipt_2329.jpg
# Size: 0.69 MB
# Saved: processed_json_images/receipt_2329.json
# Processing: receipt_2330.jpg
# Size: 0.85 MB
# Saved: processed_json_images/receipt_2330.json
# Processing: receipt_2331.jpg
# Size: 0.87 MB
# Saved: processed_json_images/receipt_2331.json
# Processing: receipt_2332.jpg
# Size: 0.87 MB
# Saved: processed_json_images/receipt_2332.json
# Processing: receipt_2333.jpg
# Size: 0.87 MB
# Saved: processed_json_images/receipt_2333.json
# Processing: receipt_2334.jpg
# Size: 0.69 MB
# Saved: processed_json_images/receipt_2334.json
# Processing: receipt_2335.jpg
# Size: 0.69 MB
# Saved: processed_json_images/receipt_2335.json
# Processing: receipt_2336.jpg
# Size: 0.69 MB
# Saved: processed_json_images/receipt_2336.json
# Processing: receipt_2337.jpg
# Size: 0.69 MB
# Saved: processed_json_images/receipt_2337.json
# Processing: receipt_2338.jpg
# Size: 0.69 MB
# Saved: processed_json_images/receipt_2338.json
# Processing: receipt_2339.jpg
# Size: 0.06 MB
# Saved: processed_json_images/receipt_2339.json
# Processing: receipt_2340.jpg
# Size: 0.06 MB
# Saved: processed_json_images/receipt_2340.json
# Processing: receipt_2341.jpg
# Size: 0.06 MB
# Saved: processed_json_images/receipt_2341.json
# Processing: receipt_2342.jpg
# Size: 0.06 MB
# Saved: processed_json_images/receipt_2342.json
# Processing: receipt_2343.jpg
# Size: 0.06 MB
# Saved: processed_json_images/receipt_2343.json
# Processing: receipt_2344.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2344.json
# Processing: receipt_2345.jpg
# Size: 0.12 MB
# Saved: processed_json_images/receipt_2345.json
# Processing: receipt_2346.jpg
# Size: 0.12 MB
# Saved: processed_json_images/receipt_2346.json
# Processing: receipt_2347.jpg
# Size: 0.20 MB
# Saved: processed_json_images/receipt_2347.json
# Processing: receipt_2348.jpg
# Size: 0.49 MB
# Saved: processed_json_images/receipt_2348.json
# Processing: receipt_2349.jpg
# Size: 0.49 MB
# Saved: processed_json_images/receipt_2349.json
# Processing: receipt_2350.jpg
# Size: 0.53 MB
# Saved: processed_json_images/receipt_2350.json
# Processing: receipt_2351.jpg
# Size: 0.53 MB
# Saved: processed_json_images/receipt_2351.json
# Processing: receipt_2352.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2352.json
# Processing: receipt_2353.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2353.json
# Processing: receipt_2354.jpg
# Size: 0.59 MB
# Saved: processed_json_images/receipt_2354.json
# Processing: receipt_2355.jpg
# Size: 0.59 MB
# Saved: processed_json_images/receipt_2355.json
# Processing: receipt_2356.jpg
# Size: 0.60 MB
# Saved: processed_json_images/receipt_2356.json
# Processing: receipt_2357.jpg
# Size: 0.60 MB
# Saved: processed_json_images/receipt_2357.json
# Processing: receipt_2358.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2358.json
# Processing: receipt_2359.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2359.json
# Processing: receipt_2360.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2360.json
# Processing: receipt_2361.jpg
# Size: 1.83 MB
# Saved: processed_json_images/receipt_2361.json
# Processing: receipt_2362.jpg
# Size: 0.42 MB
# Saved: processed_json_images/receipt_2362.json
# Processing: receipt_2363.jpg
# Size: 0.62 MB
# Saved: processed_json_images/receipt_2363.json
# Processing: receipt_2364.jpg
# Size: 1.84 MB
# Saved: processed_json_images/receipt_2364.json
# Processing: receipt_2365.jpg
# Size: 0.51 MB
# Saved: processed_json_images/receipt_2365.json
# Processing: receipt_2366.jpg
# Size: 0.51 MB
# Saved: processed_json_images/receipt_2366.json
# Processing: receipt_2367.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_2367.json
# Processing: receipt_2368.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_2368.json
# Processing: receipt_2369.jpg
# Size: 0.56 MB
# Saved: processed_json_images/receipt_2369.json
# Processing: receipt_2370.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2370.json
# Processing: receipt_2371.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2371.json
# Processing: receipt_2372.jpg
# Size: 0.19 MB
# Saved: processed_json_images/receipt_2372.json
# Processing: receipt_2373.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2373.json
# Processing: receipt_2374.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2374.json
# Processing: receipt_2375.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_2375.json
# Processing: receipt_2376.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_2376.json
# Processing: receipt_2377.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2377.json
# Processing: receipt_2378.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2378.json
# Processing: receipt_2379.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2379.json
# Processing: receipt_2380.jpg
# Size: 0.12 MB
# Saved: processed_json_images/receipt_2380.json
# Processing: receipt_2381.jpg
# Size: 0.17 MB
# Saved: processed_json_images/receipt_2381.json
# Processing: receipt_2382.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_2382.json
# Processing: receipt_2383.jpg
# Size: 0.19 MB
# Saved: processed_json_images/receipt_2383.json
# Processing: receipt_2384.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2384.json
# Processing: receipt_2385.jpg
# Size: 0.16 MB
# Saved: processed_json_images/receipt_2385.json
# Processing: receipt_2386.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_2386.json
# Processing: receipt_2387.jpg
# Size: 0.22 MB
# Saved: processed_json_images/receipt_2387.json
# Processing: receipt_2388.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_2388.json
# Processing: receipt_2389.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_2389.json
# Processing: receipt_2390.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_2390.json
# Processing: receipt_2391.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_2391.json
# Processing: receipt_2392.jpg
# Size: 0.12 MB
# Saved: processed_json_images/receipt_2392.json
# Processing: receipt_2393.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_2393.json
# Processing: receipt_2394.jpg
# Size: 0.08 MB
# Saved: processed_json_images/receipt_2394.json
# Processing: receipt_2395.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_2395.json
# Processing: receipt_2396.jpg
# Size: 0.20 MB
# Saved: processed_json_images/receipt_2396.json
# Processing: receipt_2397.jpg
# Size: 0.20 MB
# Saved: processed_json_images/receipt_2397.json
# Processing: receipt_2398.jpg
# Size: 0.20 MB
# Saved: processed_json_images/receipt_2398.json
# Processing: receipt_2399.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_2399.json
# Processing: receipt_2400.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2400.json
# Processing: receipt_2401.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2401.json
# Processing: receipt_2402.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2402.json
# Processing: receipt_2403.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2403.json
# Processing: receipt_2404.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2404.json
# Processing: receipt_2405.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2405.json
# Processing: receipt_2406.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2406.json
# Processing: receipt_2407.jpg
# Size: 0.12 MB
# Saved: processed_json_images/receipt_2407.json
# Processing: receipt_2408.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_2408.json
# Processing: receipt_2409.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_2409.json
# Processing: receipt_2410.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2410.json
# Processing: receipt_2411.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2411.json
# Processing: receipt_2412.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2412.json
# Processing: receipt_2413.jpg
# Size: 0.10 MB
# Saved: processed_json_images/receipt_2413.json
# Processing: receipt_2414.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_2414.json
# Processing: receipt_2415.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_2415.json
# Processing: receipt_2416.jpg
# Size: 0.12 MB
# Saved: processed_json_images/receipt_2416.json
# Processing: receipt_2417.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_2417.json
# Processing: receipt_2418.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2418.json
# Processing: receipt_2419.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_2419.json
# Processing: receipt_2420.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2420.json
# Processing: receipt_2421.jpg
# Size: 0.15 MB
# Saved: processed_json_images/receipt_2421.json
# Processing: receipt_2422.jpg
# Size: 0.19 MB
# Saved: processed_json_images/receipt_2422.json
# Processing: receipt_2423.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2423.json
# Processing: receipt_2424.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_2424.json
# Processing: receipt_2425.jpg
# Size: 0.17 MB
# Saved: processed_json_images/receipt_2425.json
# Processing: receipt_2426.jpg
# Size: 0.17 MB
# Saved: processed_json_images/receipt_2426.json
# Processing: receipt_2427.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2427.json
# Processing: receipt_2428.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2428.json
# Processing: receipt_2429.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_2429.json
# Processing: receipt_2430.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_2430.json
# Processing: receipt_2431.jpg
# Size: 0.15 MB
# Saved: processed_json_images/receipt_2431.json
# Processing: receipt_2432.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_2432.json
# Processing: receipt_2433.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2433.json
# Processing: receipt_2434.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2434.json
# Processing: receipt_2435.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_2435.json
# Processing: receipt_2436.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_2436.json
# Processing: receipt_2437.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2437.json
# Processing: receipt_2438.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2438.json
# Processing: receipt_2439.jpg
# Size: 0.44 MB
# Saved: processed_json_images/receipt_2439.json
# Processing: receipt_2440.jpg
# Size: 0.44 MB
# Saved: processed_json_images/receipt_2440.json
# Processing: receipt_2441.jpg
# Size: 0.15 MB
# Saved: processed_json_images/receipt_2441.json
# Processing: receipt_2442.jpg
# Size: 0.15 MB
# Saved: processed_json_images/receipt_2442.json
# Processing: receipt_2443.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_2443.json
# Processing: receipt_2444.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_2444.json
# Processing: receipt_2445.jpg
# Size: 0.17 MB
# Saved: processed_json_images/receipt_2445.json
# Processing: receipt_2446.jpg
# Size: 0.17 MB
# Saved: processed_json_images/receipt_2446.json
# Processing: receipt_2447.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_2447.json
# Processing: receipt_2448.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2448.json
# Processing: receipt_2449.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_2449.json
# Processing: receipt_2450.jpg
# Size: 0.66 MB
# Saved: processed_json_images/receipt_2450.json
# Processing: receipt_2451.jpg
# Size: 0.48 MB
# Saved: processed_json_images/receipt_2451.json
# Processing: receipt_2452.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2452.json
# Processing: receipt_2453.jpg
# Size: 0.28 MB
# Saved: processed_json_images/receipt_2453.json
# Processing: receipt_2454.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2454.json
# Processing: receipt_2455.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_2455.json
# Processing: receipt_2456.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_2456.json
# Processing: receipt_2457.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_2457.json
# Processing: receipt_2458.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_2458.json
# Processing: receipt_2459.jpg
# Size: 0.38 MB
# Saved: processed_json_images/receipt_2459.json
# Processing: receipt_2460.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_2460.json
# Processing: receipt_2461.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2461.json
# Processing: receipt_2462.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2462.json
# Processing: receipt_2463.jpg
# Size: 0.40 MB
# Saved: processed_json_images/receipt_2463.json
# Processing: receipt_2464.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2464.json
# Processing: receipt_2465.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2465.json
# Processing: receipt_2466.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_2466.json
# Processing: receipt_2467.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_2467.json
# Processing: receipt_2468.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_2468.json
# Processing: receipt_2469.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_2469.json
# Processing: receipt_2470.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2470.json
# Processing: receipt_2471.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2471.json
# Processing: receipt_2472.jpg
# Size: 0.52 MB
# Saved: processed_json_images/receipt_2472.json
# Processing: receipt_2473.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2473.json
# Processing: receipt_2474.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2474.json
# Processing: receipt_2475.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2475.json
# Processing: receipt_2476.jpg
# Size: 0.93 MB
# Saved: processed_json_images/receipt_2476.json
# Processing: receipt_2477.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2477.json
# Processing: receipt_2478.jpg
# Size: 1.00 MB
# Saved: processed_json_images/receipt_2478.json
# Processing: receipt_2479.jpg
# Size: 1.00 MB
# Saved: processed_json_images/receipt_2479.json
# Processing: receipt_2480.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2480.json
# Processing: receipt_2481.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2481.json
# Processing: receipt_2482.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2482.json
# Processing: receipt_2483.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2483.json
# Processing: receipt_2484.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2484.json
# Processing: receipt_2485.jpg
# Size: 0.50 MB
# Saved: processed_json_images/receipt_2485.json
# Processing: receipt_2486.jpg
# Size: 0.50 MB
# Saved: processed_json_images/receipt_2486.json
# Processing: receipt_2487.jpg
# Size: 0.50 MB
# Saved: processed_json_images/receipt_2487.json
# Processing: receipt_2488.jpg
# Size: 0.50 MB
# Saved: processed_json_images/receipt_2488.json
# Processing: receipt_2489.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2489.json
# Processing: receipt_2490.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2490.json
# Processing: receipt_2491.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2491.json
# Processing: receipt_2492.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2492.json
# Processing: receipt_2493.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2493.json
# Processing: receipt_2494.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2494.json
# Processing: receipt_2495.jpg
# Size: 0.52 MB
# Saved: processed_json_images/receipt_2495.json
# Processing: receipt_2496.jpg
# Size: 0.63 MB
# Saved: processed_json_images/receipt_2496.json
# Processing: receipt_2497.jpg
# Size: 0.63 MB
# Saved: processed_json_images/receipt_2497.json
# Processing: receipt_2498.jpg
# Size: 0.59 MB
# Saved: processed_json_images/receipt_2498.json
# Processing: receipt_2499.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2499.json
# Processing: receipt_2500.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2500.json
# Processing: receipt_2501.jpg
# Size: 0.56 MB
# Saved: processed_json_images/receipt_2501.json
# Processing: receipt_2502.jpg
# Size: 0.49 MB
# Saved: processed_json_images/receipt_2502.json
# Processing: receipt_2503.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_2503.json
# Processing: receipt_2504.jpg
# Size: 0.51 MB
# Saved: processed_json_images/receipt_2504.json
# Processing: receipt_2505.jpg
# Size: 0.52 MB
# Saved: processed_json_images/receipt_2505.json
# Processing: receipt_2506.jpg
# Size: 0.52 MB
# Saved: processed_json_images/receipt_2506.json
# Processing: receipt_2507.jpg
# Size: 0.67 MB
# Saved: processed_json_images/receipt_2507.json
# Processing: receipt_2508.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2508.json
# Processing: receipt_2509.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2509.json
# Processing: receipt_2510.jpg
# Size: 0.43 MB
# Saved: processed_json_images/receipt_2510.json
# Processing: receipt_2511.jpg
# Size: 0.76 MB
# Saved: processed_json_images/receipt_2511.json
# Processing: receipt_2512.jpg
# Size: 0.56 MB
# Saved: processed_json_images/receipt_2512.json
# Processing: receipt_2513.jpg
# Size: 0.69 MB
# Saved: processed_json_images/receipt_2513.json
# Processing: receipt_2514.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2514.json
# Processing: receipt_2515.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2515.json
# Processing: receipt_2516.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2516.json
# Processing: receipt_2517.jpg
# Size: 0.44 MB
# Saved: processed_json_images/receipt_2517.json
# Processing: receipt_2518.jpg
# Size: 0.46 MB
# Saved: processed_json_images/receipt_2518.json
# Processing: receipt_2519.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2519.json
# Processing: receipt_2520.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2520.json
# Processing: receipt_2521.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2521.json
# Processing: receipt_2522.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2522.json
# Processing: receipt_2523.jpg
# Size: 0.50 MB
# Saved: processed_json_images/receipt_2523.json
# Processing: receipt_2524.jpg
# Size: 0.50 MB
# Saved: processed_json_images/receipt_2524.json
# Processing: receipt_2525.jpg
# Size: 0.40 MB
# Saved: processed_json_images/receipt_2525.json
# Processing: receipt_2526.jpg
# Size: 0.40 MB
# Saved: processed_json_images/receipt_2526.json
# Processing: receipt_2527.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2527.json
# Processing: receipt_2528.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2528.json
# Processing: receipt_2529.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2529.json
# Processing: receipt_2530.jpg
# Size: 0.62 MB
# Saved: processed_json_images/receipt_2530.json
# Processing: receipt_2531.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2531.json
# Processing: receipt_2532.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2532.json
# Processing: receipt_2533.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2533.json
# Processing: receipt_2534.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2534.json
# Processing: receipt_2535.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2535.json
# Processing: receipt_2536.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2536.json
# Processing: receipt_2537.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2537.json
# Processing: receipt_2538.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2538.json
# Processing: receipt_2539.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2539.json
# Processing: receipt_2540.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2540.json
# Processing: receipt_2541.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2541.json
# Processing: receipt_2542.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2542.json
# Processing: receipt_2543.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2543.json
# Processing: receipt_2544.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2544.json
# Processing: receipt_2545.jpg
# Size: 0.38 MB
# Saved: processed_json_images/receipt_2545.json
# Processing: receipt_2546.jpg
# Size: 0.38 MB
# Saved: processed_json_images/receipt_2546.json
# Processing: receipt_2547.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2547.json
# Processing: receipt_2548.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2548.json
# Processing: receipt_2549.jpg
# Size: 0.22 MB
# Saved: processed_json_images/receipt_2549.json
# Processing: receipt_2550.jpg
# Size: 0.22 MB
# Saved: processed_json_images/receipt_2550.json
# Processing: receipt_2551.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2551.json
# Processing: receipt_2552.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2552.json
# Processing: receipt_2553.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2553.json
# Processing: receipt_2554.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2554.json
# Processing: receipt_2555.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_2555.json
# Processing: receipt_2556.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2556.json
# Processing: receipt_2557.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2557.json
# Processing: receipt_2558.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2558.json
# Processing: receipt_2559.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_2559.json
# Processing: receipt_2560.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2560.json
# Processing: receipt_2561.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2561.json
# Processing: receipt_2562.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2562.json
# Processing: receipt_2563.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2563.json
# Processing: receipt_2564.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2564.json
# Processing: receipt_2565.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2565.json
# Processing: receipt_2566.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2566.json
# Processing: receipt_2567.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2567.json
# Processing: receipt_2568.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2568.json
# Processing: receipt_2569.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2569.json
# Processing: receipt_2570.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2570.json
# Processing: receipt_2571.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2571.json
# Processing: receipt_2572.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2572.json
# Processing: receipt_2573.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2573.json
# Processing: receipt_2574.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2574.json
# Processing: receipt_2575.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2575.json
# Processing: receipt_2576.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2576.json
# Processing: receipt_2577.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2577.json
# Processing: receipt_2578.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2578.json
# Processing: receipt_2579.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2579.json
# Processing: receipt_2580.jpg
# Size: 0.12 MB
# Saved: processed_json_images/receipt_2580.json
# Processing: receipt_2581.jpg
# Size: 0.12 MB
# Saved: processed_json_images/receipt_2581.json
# Processing: receipt_2582.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2582.json
# Processing: receipt_2583.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2583.json
# Processing: receipt_2584.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2584.json
# Processing: receipt_2585.jpg
# Size: 0.28 MB
# Saved: processed_json_images/receipt_2585.json
# Processing: receipt_2586.jpg
# Size: 0.28 MB
# Saved: processed_json_images/receipt_2586.json
# Processing: receipt_2587.jpg
# Size: 0.28 MB
# Saved: processed_json_images/receipt_2587.json
# Processing: receipt_2588.jpg
# Size: 0.68 MB
# Saved: processed_json_images/receipt_2588.json
# Processing: receipt_2589.jpg
# Size: 0.68 MB
# Saved: processed_json_images/receipt_2589.json
# Processing: receipt_2590.jpg
# Size: 0.82 MB
# Saved: processed_json_images/receipt_2590.json
# Processing: receipt_2591.jpg
# Size: 0.73 MB
# Saved: processed_json_images/receipt_2591.json
# Processing: receipt_2592.jpg
# Size: 1.35 MB
# Saved: processed_json_images/receipt_2592.json
# Processing: receipt_2593.jpg
# Size: 1.19 MB
# Saved: processed_json_images/receipt_2593.json
# Processing: receipt_2594.jpg
# Size: 0.83 MB
# Saved: processed_json_images/receipt_2594.json
# Processing: receipt_2595.jpg
# Size: 0.52 MB
# Saved: processed_json_images/receipt_2595.json
# Processing: receipt_2596.jpg
# Size: 0.94 MB
# Saved: processed_json_images/receipt_2596.json
# Processing: receipt_2597.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_2597.json
# Processing: receipt_2598.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2598.json
# Processing: receipt_2599.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2599.json
# Processing: receipt_2600.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2600.json
# Processing: receipt_2601.jpg
# Size: 0.16 MB
# Saved: processed_json_images/receipt_2601.json
# Processing: receipt_2602.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2602.json
# Processing: receipt_2603.jpg
# Size: 0.16 MB
# Saved: processed_json_images/receipt_2603.json
# Processing: receipt_2604.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2604.json
# Processing: receipt_2605.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2605.json
# Processing: receipt_2606.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2606.json
# Processing: receipt_2607.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2607.json
# Processing: receipt_2608.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2608.json
# Processing: receipt_2609.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2609.json
# Processing: receipt_2610.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2610.json
# Processing: receipt_2611.jpg
# Size: 0.22 MB
# Saved: processed_json_images/receipt_2611.json
# Processing: receipt_2612.jpg
# Size: 0.22 MB
# Saved: processed_json_images/receipt_2612.json
# Processing: receipt_2613.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2613.json
# Processing: receipt_2614.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2614.json
# Processing: receipt_2615.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2615.json
# Processing: receipt_2616.jpg
# Size: 0.22 MB
# Saved: processed_json_images/receipt_2616.json
# Processing: receipt_2617.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2617.json
# Processing: receipt_2618.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2618.json
# Processing: receipt_2619.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_2619.json
# Processing: receipt_2620.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2620.json
# Processing: receipt_2621.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2621.json
# Processing: receipt_2622.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_2622.json
# Processing: receipt_2623.jpg
# Size: 0.16 MB
# Saved: processed_json_images/receipt_2623.json
# Processing: receipt_2624.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2624.json
# Processing: receipt_2625.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2625.json
# Processing: receipt_2626.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2626.json
# Processing: receipt_2627.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2627.json
# Processing: receipt_2628.jpg
# Size: 0.38 MB
# Saved: processed_json_images/receipt_2628.json
# Processing: receipt_2629.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2629.json
# Processing: receipt_2630.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2630.json
# Processing: receipt_2631.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2631.json
# Processing: receipt_2632.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_2632.json
# Processing: receipt_2633.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_2633.json
# Processing: receipt_2634.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2634.json
# Processing: receipt_2635.jpg
# Size: 0.28 MB
# Saved: processed_json_images/receipt_2635.json
# Processing: receipt_2636.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2636.json
# Processing: receipt_2637.jpg
# Size: 0.28 MB
# Saved: processed_json_images/receipt_2637.json
# Processing: receipt_2638.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2638.json
# Processing: receipt_2639.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2639.json
# Processing: receipt_2640.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_2640.json
# Processing: receipt_2641.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_2641.json
# Processing: receipt_2642.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2642.json
# Processing: receipt_2643.jpg
# Size: 0.42 MB
# Saved: processed_json_images/receipt_2643.json
# Processing: receipt_2644.jpg
# Size: 0.20 MB
# Saved: processed_json_images/receipt_2644.json
# Processing: receipt_2645.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_2645.json
# Processing: receipt_2646.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_2646.json
# Processing: receipt_2647.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_2647.json
# Processing: receipt_2648.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_2648.json
# Processing: receipt_2649.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2649.json
# Processing: receipt_2650.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2650.json
# Processing: receipt_2651.jpg
# Size: 0.38 MB
# Saved: processed_json_images/receipt_2651.json
# Processing: receipt_2652.jpg
# Size: 0.68 MB
# Saved: processed_json_images/receipt_2652.json
# Processing: receipt_2653.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2653.json
# Processing: receipt_2654.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2654.json
# Processing: receipt_2655.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_2655.json
# Processing: receipt_2656.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2656.json
# Processing: receipt_2657.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_2657.json
# Processing: receipt_2658.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_2658.json
# Processing: receipt_2659.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2659.json
# Processing: receipt_2660.jpg
# Size: 0.19 MB
# Saved: processed_json_images/receipt_2660.json
# Processing: receipt_2661.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_2661.json
# Processing: receipt_2662.jpg
# Size: 0.28 MB
# Saved: processed_json_images/receipt_2662.json
# Processing: receipt_2663.jpg
# Size: 0.45 MB
# Saved: processed_json_images/receipt_2663.json
# Processing: receipt_2664.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2664.json
# Processing: receipt_2665.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2665.json
# Processing: receipt_2666.jpg
# Size: 0.17 MB
# Saved: processed_json_images/receipt_2666.json
# Processing: receipt_2667.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_2667.json
# Processing: receipt_2668.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2668.json
# Processing: receipt_2669.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2669.json
# Processing: receipt_2670.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_2670.json
# Processing: receipt_2671.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2671.json
# Processing: receipt_2672.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_2672.json
# Processing: receipt_2673.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2673.json
# Processing: receipt_2674.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_2674.json
# Processing: receipt_2675.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2675.json
# Processing: receipt_2676.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2676.json
# Processing: receipt_2677.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2677.json
# Processing: receipt_2678.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2678.json
# Processing: receipt_2679.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2679.json
# Processing: receipt_2680.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2680.json
# Processing: receipt_2681.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2681.json
# Processing: receipt_2682.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2682.json
# Processing: receipt_2683.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2683.json
# Processing: receipt_2684.jpg
# Size: 0.41 MB
# Saved: processed_json_images/receipt_2684.json
# Processing: receipt_2685.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_2685.json
# Processing: receipt_2686.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2686.json
# Processing: receipt_2687.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2687.json
# Processing: receipt_2688.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2688.json
# Processing: receipt_2689.jpg
# Size: 0.38 MB
# Saved: processed_json_images/receipt_2689.json
# Processing: receipt_2690.jpg
# Size: 0.52 MB
# Saved: processed_json_images/receipt_2690.json
# Processing: receipt_2691.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2691.json
# Processing: receipt_2692.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2692.json
# Processing: receipt_2693.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_2693.json
# Processing: receipt_2694.jpg
# Size: 0.41 MB
# Saved: processed_json_images/receipt_2694.json
# Processing: receipt_2695.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2695.json
# Processing: receipt_2696.jpg
# Size: 0.19 MB
# Saved: processed_json_images/receipt_2696.json
# Processing: receipt_2697.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2697.json
# Processing: receipt_2698.jpg
# Size: 0.61 MB
# Saved: processed_json_images/receipt_2698.json
# Processing: receipt_2699.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2699.json
# Processing: receipt_2700.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2700.json
# Processing: receipt_2701.jpg
# Size: 0.53 MB
# Saved: processed_json_images/receipt_2701.json
# Processing: receipt_2702.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2702.json
# Processing: receipt_2703.jpg
# Size: 0.50 MB
# Saved: processed_json_images/receipt_2703.json
# Processing: receipt_2704.jpg
# Size: 0.38 MB
# Saved: processed_json_images/receipt_2704.json
# Processing: receipt_2705.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2705.json
# Processing: receipt_2706.jpg
# Size: 0.43 MB
# Saved: processed_json_images/receipt_2706.json
# Processing: receipt_2707.jpg
# Size: 0.43 MB
# Saved: processed_json_images/receipt_2707.json
# Processing: receipt_2708.jpg
# Size: 0.76 MB
# Saved: processed_json_images/receipt_2708.json
# Processing: receipt_2709.jpg
# Size: 0.51 MB
# Saved: processed_json_images/receipt_2709.json
# Processing: receipt_2710.jpg
# Size: 0.46 MB
# Saved: processed_json_images/receipt_2710.json
# Processing: receipt_2711.jpg
# Size: 0.46 MB
# Saved: processed_json_images/receipt_2711.json
# Processing: receipt_2712.jpg
# Size: 0.45 MB
# Saved: processed_json_images/receipt_2712.json
# Processing: receipt_2713.jpg
# Size: 0.53 MB
# Saved: processed_json_images/receipt_2713.json
# Processing: receipt_2714.jpg
# Size: 0.38 MB
# Saved: processed_json_images/receipt_2714.json
# Processing: receipt_2715.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2715.json
# Processing: receipt_2716.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2716.json
# Processing: receipt_2717.jpg
# Size: 0.46 MB
# Saved: processed_json_images/receipt_2717.json
# Processing: receipt_2718.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2718.json
# Processing: receipt_2719.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2719.json
# Processing: receipt_2720.jpg
# Size: 0.36 MB
# Saved: processed_json_images/receipt_2720.json
# Processing: receipt_2721.jpg
# Size: 0.46 MB
# Saved: processed_json_images/receipt_2721.json
# Processing: receipt_2722.jpg
# Size: 0.46 MB
# Saved: processed_json_images/receipt_2722.json
# Processing: receipt_2723.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2723.json
# Processing: receipt_2724.jpg
# Size: 0.44 MB
# Saved: processed_json_images/receipt_2724.json
# Processing: receipt_2725.jpg
# Size: 0.44 MB
# Saved: processed_json_images/receipt_2725.json
# Processing: receipt_2726.jpg
# Size: 0.40 MB
# Saved: processed_json_images/receipt_2726.json
# Processing: receipt_2727.jpg
# Size: 0.40 MB
# Saved: processed_json_images/receipt_2727.json
# Processing: receipt_2728.jpg
# Size: 0.43 MB
# Saved: processed_json_images/receipt_2728.json
# Processing: receipt_2729.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2729.json
# Processing: receipt_2730.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2730.json
# Processing: receipt_2731.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2731.json
# Processing: receipt_2732.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2732.json
# Processing: receipt_2733.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2733.json
# Processing: receipt_2734.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2734.json
# Processing: receipt_2735.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2735.json
# Processing: receipt_2736.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2736.json
# Processing: receipt_2737.jpg
# Size: 0.43 MB
# Saved: processed_json_images/receipt_2737.json
# Processing: receipt_2738.jpg
# Size: 0.43 MB
# Saved: processed_json_images/receipt_2738.json
# Processing: receipt_2739.jpg
# Size: 0.43 MB
# Saved: processed_json_images/receipt_2739.json
# Processing: receipt_2740.jpg
# Size: 0.44 MB
# Saved: processed_json_images/receipt_2740.json
# Processing: receipt_2741.jpg
# Size: 0.44 MB
# Saved: processed_json_images/receipt_2741.json
# Processing: receipt_2742.jpg
# Size: 0.44 MB
# Saved: processed_json_images/receipt_2742.json
# Processing: receipt_2743.jpg
# Size: 0.41 MB
# Saved: processed_json_images/receipt_2743.json
# Processing: receipt_2744.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2744.json
# Processing: receipt_2745.jpg
# Size: 0.51 MB
# Saved: processed_json_images/receipt_2745.json
# Processing: receipt_2746.jpg
# Size: 0.46 MB
# Saved: processed_json_images/receipt_2746.json
# Processing: receipt_2747.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2747.json
# Processing: receipt_2748.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2748.json
# Processing: receipt_2749.jpg
# Size: 1.03 MB
# Saved: processed_json_images/receipt_2749.json
# Processing: receipt_2750.jpg
# Size: 1.08 MB
# Saved: processed_json_images/receipt_2750.json
# Processing: receipt_2751.jpg
# Size: 0.46 MB
# Saved: processed_json_images/receipt_2751.json
# Processing: receipt_2752.jpg
# Size: 0.99 MB
# Saved: processed_json_images/receipt_2752.json
# Processing: receipt_2753.jpg
# Size: 0.58 MB
# Saved: processed_json_images/receipt_2753.json
# Processing: receipt_2754.jpg
# Size: 0.46 MB
# Saved: processed_json_images/receipt_2754.json
# Processing: receipt_2755.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2755.json
# Processing: receipt_2756.jpg
# Size: 0.55 MB
# Saved: processed_json_images/receipt_2756.json
# Processing: receipt_2757.jpg
# Size: 0.55 MB
# Saved: processed_json_images/receipt_2757.json
# Processing: receipt_2758.jpg
# Size: 0.71 MB
# Saved: processed_json_images/receipt_2758.json
# Processing: receipt_2759.jpg
# Size: 0.49 MB
# Saved: processed_json_images/receipt_2759.json
# Processing: receipt_2760.jpg
# Size: 0.49 MB
# Saved: processed_json_images/receipt_2760.json
# Processing: receipt_2761.jpg
# Size: 0.66 MB
# Saved: processed_json_images/receipt_2761.json
# Processing: receipt_2762.jpg
# Size: 0.57 MB
# Saved: processed_json_images/receipt_2762.json
# Processing: receipt_2763.jpg
# Size: 0.55 MB
# Saved: processed_json_images/receipt_2763.json
# Processing: receipt_2764.jpg
# Size: 0.10 MB
# Saved: processed_json_images/receipt_2764.json
# Processing: receipt_2765.jpg
# Size: 0.53 MB
# Saved: processed_json_images/receipt_2765.json
# Processing: receipt_2766.jpg
# Size: 0.48 MB
# Saved: processed_json_images/receipt_2766.json
# Processing: receipt_2767.jpg
# Size: 0.37 MB
# Saved: processed_json_images/receipt_2767.json
# Processing: receipt_2768.jpg
# Size: 0.42 MB
# Saved: processed_json_images/receipt_2768.json
# Processing: receipt_2769.jpg
# Size: 0.59 MB
# Saved: processed_json_images/receipt_2769.json
# Processing: receipt_2770.jpg
# Size: 0.48 MB
# Saved: processed_json_images/receipt_2770.json
# Processing: receipt_2771.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2771.json
# Processing: receipt_2772.jpg
# Size: 0.62 MB
# Saved: processed_json_images/receipt_2772.json
# Processing: receipt_2773.jpg
# Size: 0.69 MB
# Saved: processed_json_images/receipt_2773.json
# Processing: receipt_2774.jpg
# Size: 0.52 MB
# Saved: processed_json_images/receipt_2774.json
# Processing: receipt_2775.jpg
# Size: 0.60 MB
# Saved: processed_json_images/receipt_2775.json
# Processing: receipt_2776.jpg
# Size: 0.50 MB
# Saved: processed_json_images/receipt_2776.json
# Processing: receipt_2777.jpg
# Size: 0.38 MB
# Saved: processed_json_images/receipt_2777.json
# Processing: receipt_2778.jpg
# Size: 0.54 MB
# Saved: processed_json_images/receipt_2778.json
# Processing: receipt_2779.jpg
# Size: 0.45 MB
# Saved: processed_json_images/receipt_2779.json
# Processing: receipt_2780.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_2780.json
# Processing: receipt_2781.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_2781.json
# Processing: receipt_2782.jpg
# Size: 0.48 MB
# Saved: processed_json_images/receipt_2782.json
# Processing: receipt_2783.jpg
# Size: 0.58 MB
# Saved: processed_json_images/receipt_2783.json
# Processing: receipt_2784.jpg
# Size: 0.63 MB
# Saved: processed_json_images/receipt_2784.json
# Processing: receipt_2785.jpg
# Size: 0.51 MB
# Saved: processed_json_images/receipt_2785.json
# Processing: receipt_2786.jpg
# Size: 0.51 MB
# Saved: processed_json_images/receipt_2786.json
# Processing: receipt_2787.jpg
# Size: 0.60 MB
# Saved: processed_json_images/receipt_2787.json
# Processing: receipt_2788.jpg
# Size: 0.60 MB
# Saved: processed_json_images/receipt_2788.json
# Processing: receipt_2789.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2789.json
# Processing: receipt_2790.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2790.json
# Processing: receipt_2791.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_2791.json
# Processing: receipt_2792.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_2792.json
# Processing: receipt_2793.jpg
# Size: 0.67 MB
# Saved: processed_json_images/receipt_2793.json
# Processing: receipt_2794.jpg
# Size: 0.67 MB
# Saved: processed_json_images/receipt_2794.json
# Processing: receipt_2795.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_2795.json
# Processing: receipt_2796.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_2796.json
# Processing: receipt_2797.jpg
# Size: 0.46 MB
# Saved: processed_json_images/receipt_2797.json
# Processing: receipt_2798.jpg
# Size: 0.39 MB
# Saved: processed_json_images/receipt_2798.json
# Processing: receipt_2799.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2799.json
# Processing: receipt_2800.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_2800.json
# Processing: receipt_2801.jpg
# Size: 0.17 MB
# Saved: processed_json_images/receipt_2801.json
# Processing: receipt_2802.jpg
# Size: 0.17 MB
# Saved: processed_json_images/receipt_2802.json
# Processing: receipt_2803.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2803.json
# Processing: receipt_2804.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2804.json
# Processing: receipt_2805.jpg
# Size: 0.40 MB
# Saved: processed_json_images/receipt_2805.json
# Processing: receipt_2806.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_2806.json
# Processing: receipt_2807.jpg
# Size: 0.17 MB
# Saved: processed_json_images/receipt_2807.json
# Processing: receipt_2808.jpg
# Size: 0.17 MB
# Saved: processed_json_images/receipt_2808.json
# Processing: receipt_2809.jpg
# Size: 0.17 MB
# Saved: processed_json_images/receipt_2809.json
# Processing: receipt_2810.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2810.json
# Processing: receipt_2811.jpg
# Size: 0.31 MB
# Saved: processed_json_images/receipt_2811.json
# Processing: receipt_2812.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2812.json
# Processing: receipt_2813.jpg
# Size: 0.34 MB
# Saved: processed_json_images/receipt_2813.json
# Processing: receipt_2814.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2814.json
# Processing: receipt_2815.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2815.json
# Processing: receipt_2816.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_2816.json
# Processing: receipt_2817.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2817.json
# Processing: receipt_2818.jpg
# Size: 0.35 MB
# Saved: processed_json_images/receipt_2818.json
# Processing: receipt_2819.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_2819.json
# Processing: receipt_2820.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2820.json
# Processing: receipt_2821.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2821.json
# Processing: receipt_2822.jpg
# Size: 0.47 MB
# Saved: processed_json_images/receipt_2822.json
# Processing: receipt_2823.jpg
# Size: 0.41 MB
# Saved: processed_json_images/receipt_2823.json
# Processing: receipt_2824.jpg
# Size: 0.41 MB
# Saved: processed_json_images/receipt_2824.json
# Processing: receipt_2825.jpg
# Size: 0.41 MB
# Saved: processed_json_images/receipt_2825.json
# Processing: receipt_2826.jpg
# Size: 0.41 MB
# Saved: processed_json_images/receipt_2826.json
# Processing: receipt_2827.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_2827.json
# Processing: receipt_2828.jpg
# Size: 0.21 MB
# ...
# Saved: processed_json_images/receipt_3270.json
# Processing: receipt_3271.jpg
# Size: 0.58 MB
# Saved: processed_json_images/receipt_3271.json
# Processing: receipt_3272.jpg
# Size: 0.58 MB
# Saved: processed_json_images/receipt_3272.json
# Processing: receipt_3273.jpg
# Size: 0.58 MB
# Saved: processed_json_images/receipt_3273.json
# Processing: receipt_3274.jpg
# Size: 0.58 MB
# Saved: processed_json_images/receipt_3274.json
# Processing: receipt_3275.jpg
# Size: 0.64 MB
# Saved: processed_json_images/receipt_3275.json
# Processing: receipt_3276.jpg
# Size: 0.72 MB
# Saved: processed_json_images/receipt_3276.json
# Processing: receipt_3277.jpg
# Size: 0.72 MB
# Saved: processed_json_images/receipt_3277.json
# Processing: receipt_3278.jpg
# Size: 0.65 MB
# Saved: processed_json_images/receipt_3278.json
# Processing: receipt_3279.jpg
# Size: 0.65 MB
# Saved: processed_json_images/receipt_3279.json
# Processing: receipt_3280.jpg
# Size: 0.68 MB
# Saved: processed_json_images/receipt_3280.json
# Processing: receipt_3281.jpg
# Size: 0.68 MB
# Saved: processed_json_images/receipt_3281.json
# Processing: receipt_3282.jpg
# Size: 0.73 MB
# Saved: processed_json_images/receipt_3282.json
# Processing: receipt_3283.jpg
# Size: 0.73 MB
# Saved: processed_json_images/receipt_3283.json
# Processing: receipt_3284.jpg
# Size: 0.77 MB
# Saved: processed_json_images/receipt_3284.json
# Processing: receipt_3285.jpg
# Size: 0.72 MB
# Saved: processed_json_images/receipt_3285.json
# Processing: receipt_3286.jpg
# Size: 0.65 MB
# Saved: processed_json_images/receipt_3286.json
# Processing: receipt_3287.jpg
# Size: 0.57 MB
# Saved: processed_json_images/receipt_3287.json
# Processing: receipt_3288.jpg
# Size: 0.57 MB
# Saved: processed_json_images/receipt_3288.json
# Processing: receipt_3289.jpg
# Size: 0.78 MB
# Saved: processed_json_images/receipt_3289.json
# Processing: receipt_3290.jpg
# Size: 0.65 MB
# Saved: processed_json_images/receipt_3290.json
# Processing: receipt_3291.jpg
# Size: 0.71 MB
# Saved: processed_json_images/receipt_3291.json
# Processing: receipt_3292.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_3292.json
# Processing: receipt_3293.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_3293.json
# Processing: receipt_3294.jpg
# Size: 0.16 MB
# Saved: processed_json_images/receipt_3294.json
# Processing: receipt_3295.jpg
# Size: 1.16 MB
# Saved: processed_json_images/receipt_3295.json
# Processing: receipt_3296.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_3296.json
# Processing: receipt_3297.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_3297.json
# Processing: receipt_3298.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_3298.json
# Processing: receipt_3299.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_3299.json
# Processing: receipt_3300.jpg
# Size: 1.81 MB
# Saved: processed_json_images/receipt_3300.json
# Processing: receipt_3301.jpg
# Size: 1.42 MB
# Saved: processed_json_images/receipt_3301.json
# Processing: receipt_3302.jpg
# Size: 1.58 MB
# Saved: processed_json_images/receipt_3302.json
# Processing: receipt_3303.jpg
# Size: 1.44 MB
# Saved: processed_json_images/receipt_3303.json
# Processing: receipt_3304.jpg
# Size: 2.05 MB
# Saved: processed_json_images/receipt_3304.json
# Processing: receipt_3305.jpg
# Size: 1.86 MB
# Saved: processed_json_images/receipt_3305.json
# Processing: receipt_3306.jpg
# Size: 3.15 MB
# Saved: processed_json_images/receipt_3306.json
# Processing: receipt_3307.jpg
# Size: 1.73 MB
# Saved: processed_json_images/receipt_3307.json
# Processing: receipt_3308.jpg
# Size: 1.89 MB
# Saved: processed_json_images/receipt_3308.json
# Processing: receipt_3309.jpg
# Size: 1.99 MB
# Saved: processed_json_images/receipt_3309.json
# Processing: receipt_3310.jpg
# Size: 2.46 MB
# Saved: processed_json_images/receipt_3310.json
# Processing: receipt_3311.jpg
# Size: 3.16 MB
# Saved: processed_json_images/receipt_3311.json
# Processing: receipt_3312.jpg
# Size: 2.06 MB
# Saved: processed_json_images/receipt_3312.json
# Processing: receipt_3313.jpg
# Size: 2.79 MB
# Saved: processed_json_images/receipt_3313.json
# Processing: receipt_3314.jpg
# Size: 1.77 MB
# Saved: processed_json_images/receipt_3314.json
# Processing: receipt_3315.jpg
# Size: 3.46 MB
# Saved: processed_json_images/receipt_3315.json
# Processing: receipt_3316.jpg
# Size: 1.55 MB
# Saved: processed_json_images/receipt_3316.json
# Processing: receipt_3317.jpg
# Size: 1.55 MB
# Saved: processed_json_images/receipt_3317.json
# Processing: receipt_3318.jpg
# Size: 1.96 MB
# Saved: processed_json_images/receipt_3318.json
# Processing: receipt_3319.jpg
# Size: 1.85 MB
# Saved: processed_json_images/receipt_3319.json
# Processing: receipt_3320.jpg
# Size: 2.30 MB
# Saved: processed_json_images/receipt_3320.json
# Processing: receipt_3321.jpg
# Size: 2.88 MB
# Saved: processed_json_images/receipt_3321.json
# Processing: receipt_3322.jpg
# Size: 1.55 MB
# Saved: processed_json_images/receipt_3322.json
# Processing: receipt_3323.jpg
# Size: 1.88 MB
# Saved: processed_json_images/receipt_3323.json
# Processing: receipt_3324.jpg
# Size: 2.67 MB
# Saved: processed_json_images/receipt_3324.json
# Processing: receipt_3325.jpg
# Size: 1.65 MB
# Saved: processed_json_images/receipt_3325.json
# Processing: receipt_3326.jpg
# Size: 4.06 MB
# Resizing receipt_3326.jpg...
# Original image size: 4.06 MB
# Resized image size: 0.04 MB
# Saved: processed_json_images/receipt_3326.json
# Processing: receipt_3327.jpg
# Size: 2.46 MB
# Saved: processed_json_images/receipt_3327.json
# Processing: receipt_3328.jpg
# Size: 1.22 MB
# Saved: processed_json_images/receipt_3328.json
# Processing: receipt_3329.jpg
# Size: 2.63 MB
# Saved: processed_json_images/receipt_3329.json
# Processing: receipt_3330.jpg
# Size: 1.69 MB
# Saved: processed_json_images/receipt_3330.json
# Processing: receipt_3331.jpg
# Size: 1.87 MB
# Saved: processed_json_images/receipt_3331.json
# Processing: receipt_3332.jpg
# Size: 2.82 MB
# Saved: processed_json_images/receipt_3332.json
# Processing: receipt_3333.jpg
# Size: 1.88 MB
# Saved: processed_json_images/receipt_3333.json
# Processing: receipt_3334.jpg
# Size: 3.03 MB
# Saved: processed_json_images/receipt_3334.json
# Processing: receipt_3335.jpg
# Size: 2.68 MB
# Saved: processed_json_images/receipt_3335.json
# Processing: receipt_3336.jpg
# Size: 1.45 MB
# Saved: processed_json_images/receipt_3336.json
# Processing: receipt_3337.jpg
# Size: 1.45 MB
# Saved: processed_json_images/receipt_3337.json
# Processing: receipt_3338.jpg
# Size: 1.52 MB
# Saved: processed_json_images/receipt_3338.json
# Processing: receipt_3339.jpg
# Size: 2.41 MB
# Saved: processed_json_images/receipt_3339.json
# Processing: receipt_3340.jpg
# Size: 1.23 MB
# Saved: processed_json_images/receipt_3340.json
# Processing: receipt_3341.jpg
# Size: 1.46 MB
# Saved: processed_json_images/receipt_3341.json
# Processing: receipt_3342.jpg
# Size: 1.45 MB
# Saved: processed_json_images/receipt_3342.json
# Processing: receipt_3343.jpg
# Size: 1.51 MB
# Saved: processed_json_images/receipt_3343.json
# Processing: receipt_3344.jpg
# Size: 1.32 MB
# Saved: processed_json_images/receipt_3344.json
# Processing: receipt_3345.jpg
# Size: 1.64 MB
# Saved: processed_json_images/receipt_3345.json
# Processing: receipt_3346.jpg
# Size: 1.89 MB
# Saved: processed_json_images/receipt_3346.json
# Processing: receipt_3347.jpg
# Size: 2.39 MB
# Saved: processed_json_images/receipt_3347.json
# Processing: receipt_3348.jpg
# Size: 1.65 MB
# Saved: processed_json_images/receipt_3348.json
# Processing: receipt_3349.jpg
# Size: 0.19 MB
# Saved: processed_json_images/receipt_3349.json
# Processing: receipt_3350.jpg
# Size: 0.29 MB
# Saved: processed_json_images/receipt_3350.json
# Processing: receipt_3351.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_3351.json
# Processing: receipt_3352.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_3352.json
# Processing: receipt_3353.jpg
# Size: 0.22 MB
# Saved: processed_json_images/receipt_3353.json
# Processing: receipt_3354.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_3354.json
# Processing: receipt_3355.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_3355.json
# Processing: receipt_3356.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_3356.json
# Processing: receipt_3357.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_3357.json
# Processing: receipt_3358.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_3358.json
# Processing: receipt_3359.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_3359.json
# Processing: receipt_3360.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_3360.json
# Processing: receipt_3361.jpg
# Size: 0.22 MB
# Saved: processed_json_images/receipt_3361.json
# Processing: receipt_3362.jpg
# Size: 0.48 MB
# Saved: processed_json_images/receipt_3362.json
# Processing: receipt_3363.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_3363.json
# Processing: receipt_3364.jpg
# Size: 0.19 MB
# Saved: processed_json_images/receipt_3364.json
# Processing: receipt_3365.jpg
# Size: 0.19 MB
# Saved: processed_json_images/receipt_3365.json
# Processing: receipt_3366.jpg
# Size: 0.44 MB
# Saved: processed_json_images/receipt_3366.json
# Processing: receipt_3367.jpg
# Size: 0.60 MB
# Saved: processed_json_images/receipt_3367.json
# Processing: receipt_3368.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_3368.json
# Processing: receipt_3369.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_3369.json
# Processing: receipt_3370.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_3370.json
# Processing: receipt_3371.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_3371.json
# Processing: receipt_3372.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_3372.json
# Processing: receipt_3373.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_3373.json
# Processing: receipt_3374.jpg
# Size: 0.28 MB
# Saved: processed_json_images/receipt_3374.json
# Processing: receipt_3375.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_3375.json
# Processing: receipt_3376.jpg
# Size: 0.22 MB
# Saved: processed_json_images/receipt_3376.json
# Processing: receipt_3377.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_3377.json
# Processing: receipt_3378.jpg
# Size: 0.20 MB
# Saved: processed_json_images/receipt_3378.json
# Processing: receipt_3379.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_3379.json
# Processing: receipt_3380.jpg
# Size: 0.22 MB
# Saved: processed_json_images/receipt_3380.json
# Processing: receipt_3381.jpg
# Size: 0.22 MB
# Saved: processed_json_images/receipt_3381.json
# Processing: receipt_3382.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_3382.json
# Processing: receipt_3383.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_3383.json
# Processing: receipt_3384.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_3384.json
# Processing: receipt_3385.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_3385.json
# Processing: receipt_3386.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_3386.json
# Processing: receipt_3387.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_3387.json
# Processing: receipt_3388.jpg
# Size: 0.38 MB
# Saved: processed_json_images/receipt_3388.json
# Processing: receipt_3389.jpg
# Size: 0.33 MB
# Saved: processed_json_images/receipt_3389.json
# Processing: receipt_3390.jpg
# Size: 0.38 MB
# Saved: processed_json_images/receipt_3390.json
# Processing: receipt_3391.jpg
# Size: 0.22 MB
# Saved: processed_json_images/receipt_3391.json
# Processing: receipt_3392.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_3392.json
# Processing: receipt_3393.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_3393.json
# Processing: receipt_3394.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_3394.json
# Processing: receipt_3395.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_3395.json
# Processing: receipt_3396.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_3396.json
# Processing: receipt_3397.jpg
# Size: 0.30 MB
# Saved: processed_json_images/receipt_3397.json
# Processing: receipt_3398.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_3398.json
# Processing: receipt_3399.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_3399.json
# Processing: receipt_3400.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_3400.json
# Processing: receipt_3401.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_3401.json
# Processing: receipt_3402.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_3402.json
# Processing: receipt_3403.jpg
# Size: 0.22 MB
# Saved: processed_json_images/receipt_3403.json
# Processing: receipt_3404.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_3404.json
# Processing: receipt_3405.jpg
# Size: 0.17 MB
# Saved: processed_json_images/receipt_3405.json
# Processing: receipt_3406.jpg
# Size: 0.11 MB
# Saved: processed_json_images/receipt_3406.json
# Processing: receipt_3407.jpg
# Size: 0.13 MB
# Saved: processed_json_images/receipt_3407.json
# Processing: receipt_3408.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_3408.json
# Processing: receipt_3409.jpg
# Size: 0.15 MB
# Saved: processed_json_images/receipt_3409.json
# Processing: receipt_3410.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_3410.json
# Processing: receipt_3411.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_3411.json
# Processing: receipt_3412.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_3412.json
# Processing: receipt_3413.jpg
# Size: 0.19 MB
# Saved: processed_json_images/receipt_3413.json
# Processing: receipt_3414.jpg
# Size: 0.19 MB
# Saved: processed_json_images/receipt_3414.json
# Processing: receipt_3415.jpg
# Size: 0.19 MB
# Saved: processed_json_images/receipt_3415.json
# Processing: receipt_3416.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_3416.json
# Processing: receipt_3417.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_3417.json
# Processing: receipt_3418.jpg
# Size: 0.25 MB
# Saved: processed_json_images/receipt_3418.json
# Processing: receipt_3419.jpg
# Size: 0.19 MB
# Saved: processed_json_images/receipt_3419.json
# Processing: receipt_3420.jpg
# Size: 0.20 MB
# Saved: processed_json_images/receipt_3420.json
# Processing: receipt_3421.jpg
# Size: 0.20 MB
# Saved: processed_json_images/receipt_3421.json
# Processing: receipt_3422.jpg
# Size: 0.20 MB
# Saved: processed_json_images/receipt_3422.json
# Processing: receipt_3423.jpg
# Size: 0.20 MB
# Saved: processed_json_images/receipt_3423.json
# Processing: receipt_3424.jpg
# Size: 0.21 MB
# Saved: processed_json_images/receipt_3424.json
# Processing: receipt_3425.jpg
# Size: 0.23 MB
# Saved: processed_json_images/receipt_3425.json
# Processing: receipt_3426.jpg
# Size: 0.20 MB
# Saved: processed_json_images/receipt_3426.json
# Processing: receipt_3427.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_3427.json
# Processing: receipt_3428.jpg
# Size: 0.11 MB
# Saved: processed_json_images/receipt_3428.json
# Processing: receipt_3429.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_3429.json
# Processing: receipt_3430.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_3430.json
# Processing: receipt_3431.jpg
# Size: 0.15 MB
# Saved: processed_json_images/receipt_3431.json
# Processing: receipt_3432.jpg
# Size: 0.32 MB
# Saved: processed_json_images/receipt_3432.json
# Processing: receipt_3433.jpg
# Size: 0.26 MB
# Saved: processed_json_images/receipt_3433.json
# Processing: receipt_3434.jpg
# Size: 0.20 MB
# Saved: processed_json_images/receipt_3434.json
# Processing: receipt_3435.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_3435.json
# Processing: receipt_3436.jpg
# Size: 0.24 MB
# Saved: processed_json_images/receipt_3436.json
# Processing: receipt_3437.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_3437.json
# Processing: receipt_3438.jpg
# Size: 0.18 MB
# Saved: processed_json_images/receipt_3438.json
# Processing: receipt_3439.jpg
# Size: 0.16 MB
# Saved: processed_json_images/receipt_3439.json
# Processing: receipt_3440.jpg
# Size: 0.19 MB
# Saved: processed_json_images/receipt_3440.json
# Processing: receipt_3441.jpg
# Size: 0.52 MB
# Saved: processed_json_images/receipt_3441.json
# Processing: receipt_3442.jpg
# Size: 0.38 MB
# Saved: processed_json_images/receipt_3442.json
# Processing: receipt_3443.jpg
# Size: 0.27 MB
# Saved: processed_json_images/receipt_3443.json
# Processing: receipt_3444.jpg
# Size: 0.15 MB
# Saved: processed_json_images/receipt_3444.json
# Processing: receipt_3445.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_3445.json
# Processing: receipt_3446.jpg
# Size: 0.14 MB
# Saved: processed_json_images/receipt_3446.json
# Processing complete! 🎉
